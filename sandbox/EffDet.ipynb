# %%
# !pip install tensorflow-model-optimization
# Out:
# ...
#      |████████████████████████████████| 211 kB 6.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 94 kB 1.7 MB/s  eta 0:00:01
# ...
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv
# WARNING: You are using pip version 21.1.1; however, version 21.1.3 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
# %cd /app/_data/automl/efficientdet
import os
import tempfile
from absl import logging
import tensorflow.compat.v1 as tf
import efficientdet_arch as legacy_arch
import hparams_config
from keras import efficientdet_keras

SEED = 111111
# Out:
# /app/_data/automl/efficientdet

# %%
config = hparams_config.get_efficientdet_config('efficientdet-d4')
config.image_size = '1024x1024'

# %%
config.num_classes=5

# %%
m = efficientdet_keras.EfficientDetNet(config=config)
#     model(tf.ones([1, 896, 1600, 3]), False)

# %%
config
# Out:
# {'name': 'efficientdet-d4', 'act_type': 'swish', 'image_size': '1024x1024', 'target_size': None, 'input_rand_hflip': True, 'jitter_min': 0.1, 'jitter_max': 2.0, 'autoaugment_policy': None, 'grid_mask': False, 'sample_image': None, 'map_freq': 5, 'num_classes': 5, 'seg_num_classes': 3, 'heads': ['object_detection'], 'skip_crowd_during_training': True, 'label_map': None, 'max_instances_per_image': 100, 'regenerate_source_id': False, 'min_level': 3, 'max_level': 7, 'num_scales': 3, 'aspect_ratios': [1.0, 2.0, 0.5], 'anchor_scale': 4.0, 'is_training_bn': True, 'momentum': 0.9, 'optimizer': 'sgd', 'learning_rate': 0.08, 'lr_warmup_init': 0.008, 'lr_warmup_epoch': 1.0, 'first_lr_drop_epoch': 200.0, 'second_lr_drop_epoch': 250.0, 'poly_lr_power': 0.9, 'clip_gradients_norm': 10.0, 'num_epochs': 300, 'data_format': 'channels_last', 'mean_rgb': [123.675, 116.28, 103.53], 'stddev_rgb': [58.395, 57.120000000000005, 57.375], 'scale_range': False, 'label_smoothing': 0.0, 'alpha': 0.25, 'gamma': 1.
# ...

# %%
m(tf.ones([1, 1024, 1024, 3]), False)
# Out:
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/keras/engine/base_layer.py:1402: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '
# ([<tf.Tensor: shape=(1, 128, 128, 45), dtype=float32, numpy=
#   array([[[[-4.59512, -4.59512, -4.59512, ..., -4.59512, -4.59512,
#             -4.59512],
#            [-4.59512, -4.59512, -4.59512, ..., -4.59512, -4.59512,
#             -4.59512],
#            [-4.59512, -4.59512, -4.59512, ..., -4.59512, -4.59512,
#             -4.59512],
#            ...,
#            [-4.59512, -4.59512, -4.59512, ..., -4.59512, -4.59512,
#             -4.59512],
#            [-4.59512, -4.59512, -4.59512, ..., -4.59512, -4.59512,
#             -4.59512],
#            [-4.59512, -4.59512, -4.59512, ..., -4.59512, -4.59512,
#             -4.59512]],
#
# ...

# %%
m.summary()
# Out:
# Model: ""
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# efficientnet-b4 (Model)      multiple                  16863832
# _________________________________________________________________
# resample_p6 (ResampleFeature multiple                  101472
# _________________________________________________________________
# resample_p7 (ResampleFeature multiple                  0
# _________________________________________________________________
# fpn_cells (FPNCells)         multiple                  3276133
# _________________________________________________________________
# class_net (ClassNet)         multiple                  239725
# _________________________________________________________________
# box_net (BoxNet)             multiple                  237700
# ...
# Total params: 20,718,862
# Trainable params: 20,551,550
# Non-trainable params: 167,312
# ...

# %%
m.layers
