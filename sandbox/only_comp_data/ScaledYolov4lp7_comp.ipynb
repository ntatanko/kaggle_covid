# %%
import ast
import os
import shutil
import torch
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import Image, clear_output
from sklearn.model_selection import StratifiedKFold, train_test_split
from tqdm import tqdm
InteractiveShell.ast_node_interactivity = "all"

# %%
# shutil.rmtree('/app/_data/ScaledYOLOv4/runs/exp0_yolov4lp7_1')

# %%
# !git clone https://github.com/WongKinYiu/ScaledYOLOv4.git
# !git clone https://github.com/thomasbrandon/mish-cuda
# %cd /app/_data/ScaledYOLOv4/mish-cuda
# !python setup.py build install
clear_output()
# %cd /app/_data/ScaledYOLOv4
! git checkout yolov4-large
# Out:
# /app/_data/ScaledYOLOv4
# M	detect.py
# M	utils/general.py
# Already on 'yolov4-large'
# Your branch is up to date with 'origin/yolov4-large'.

# %% [markdown]
# ## preparing data

# %%
df = pd.read_csv("/app/_data/bboxes.csv")
df['path'] = '/app/_data/yolo5_dataset/'+df['img']+'.jpg'
base_config = {
    "IMG_SIZE": 1024,
    "BATCH_SIZE": 10,
    "SEED": 42,
}

# %%
groupped_data =pd.pivot_table(df,index='img', values=['label', 'bbox', 'path'],aggfunc='first')
groupped_data['img'] = groupped_data.index
groupped_data = groupped_data.reset_index(drop=True)
groupped_data.head()
groupped_data['bbox'].value_counts()
# Out:
#    bbox     label                                       path           img
# 0     1   typical  /app/_data/yolo5_dataset/000a312787f2.jpg  000a312787f2
# 1     0  negative  /app/_data/yolo5_dataset/000c3a3f293f.jpg  000c3a3f293f
# 2     1   typical  /app/_data/yolo5_dataset/0012ff7358bc.jpg  0012ff7358bc
# 3     1  atypical  /app/_data/yolo5_dataset/001398f4ff4f.jpg  001398f4ff4f
# 4     1   typical  /app/_data/yolo5_dataset/001bd15d1891.jpg  001bd15d1891
# 1    4294
# 0    1736
# Name: bbox, dtype: int64

# %%
skf = StratifiedKFold(n_splits=5, random_state=base_config["SEED"], shuffle=True)
train_ids = []
val_ids = []
for train_index, valid_index in skf.split(groupped_data, groupped_data['label']):
    train_ids.append(train_index)
    val_ids.append(valid_index)

# %%
if not os.path.exists('/app/_data/yolo5_dataset/yolo4/'):
    os.mkdir('/app/_data/yolo5_dataset/yolo4/')
for i in range(5):
    train_img_path = groupped_data.loc[train_ids[i]]['path'].tolist()
    val_img_path = groupped_data.loc[val_ids[i]]['path'].tolist()
    np.savetxt("/app/_data/yolo5_dataset/yolo4/train_"+str(i)+".txt", train_img_path, fmt='%s')
    np.savetxt("/app/_data/yolo5_dataset/yolo4/val_"+str(i)+".txt", val_img_path, fmt='%s')

# %%
# for img_name in tqdm(df['img'].unique().tolist()):
#     new_df = df[df['img']==img_name].reset_index(drop=True)
#     if new_df.loc[0,'bbox']==1:
#         boxes = new_df[['class', 'x_center','y_center','width','height']].values
#         list_boxes = []
#         for box in boxes:
#             list_boxes.append(
#                 [
#                     str(box[0]),
#                     str(box[1]),
#                     str(box[2]),
#                     str(box[3]),
#                     str(box[4]),
#                 ]
#             )
#         np.savetxt("/app/_data/yolo5_dataset/yolo4/"+img_name+".txt", list_boxes, fmt='%s')
# clear_output()

# %% [markdown]
# ## Writing data.yaml and custom parameters yolov4-p7

# %%
# customize iPython writefile so we can write variables

from IPython.core.magic import register_line_cell_magic


@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, "w") as f:
        f.write(cell.format(**globals()))

# %%
if not os.path.exists("/app/_data/ScaledYOLOv4/data/DataFile"):
    os.mkdir("/app/_data/ScaledYOLOv4/data/DataFile")

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/data.yaml
# # train and val datasets (image directory or *.txt file with image paths)
# train: /app/_data/yolo5_dataset/yolo4/train_2.txt
# val: /app/_data/yolo5_dataset/yolo4/val_2.txt
# # number of classes
# nc: 1
# # class names
# names: ['opacity']

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4l.yaml
# # parameters yolov4-p7
# nc: 1  # number of classes
# depth_multiple: 1.0  # expand model depth
# width_multiple: 1.25  # expand layer channels
#
# # anchors
# anchors:
#   - [13,17,  22,25,  27,66,  55,41]  # P3/8
#   - [57,88,  112,69,  69,177,  136,138]  # P4/16
#   - [136,138,  287,114,  134,275,  268,248]  # P5/32
#   - [268,248,  232,504,  445,416,  640,640]  # P6/64
#   - [812,393,  477,808,  1070,908,  1408,1408]  # P7/128
#
# # csp-p7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, BottleneckCSP, [64]],
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 5-P3/8
#    [-1, 15, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 7-P4/16
#    [-1, 15, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]], # 9-P5/32
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 11-P6/64
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 13-P7/128
#    [-1, 7, BottleneckCSP, [1024]],  # 14
#   ]
#
# # yolov4-p7 head
# # na = len(anchors[0])
# head:
#   [[-1, 1, SPPCSP, [512]], # 15
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-6, 1, Conv, [512, 1, 1]], # route backbone P6
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 20
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-13, 1, Conv, [512, 1, 1]], # route backbone P5
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 25
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-20, 1, Conv, [256, 1, 1]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [256]], # 30
#    [-1, 1, Conv, [128, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-27, 1, Conv, [128, 1, 1]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [128]], # 35
#    [-1, 1, Conv, [256, 3, 1]],
#    [-2, 1, Conv, [256, 3, 2]],
#    [[-1, 30], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [256]], # 39
#    [-1, 1, Conv, [512, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 25], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 43
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 20], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 47
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 15], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 51
#    [-1, 1, Conv, [1024, 3, 1]],
#
#    [[36,40,44,48,52], 1, Detect, [nc, anchors]],   # Detect(P3, P4, P5, P6, P7)
#   ]

# %% [markdown]
# ## train

# %%
# !python train.py --img 1024 \
                 --batch 6 \
                 --epochs 150 \
                 --data /app/_data/ScaledYOLOv4/data/DataFile/data.yaml \
                 --cfg /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4l.yaml \
                 --weights /app/_data/ScaledYOLOv4/weights/yolov4-p7.pt \
                 --name yolov4lp7_comp_2_42 \
                 --cache
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090', total_memory=24268MB)
#
# Namespace(adam=False, batch_size=6, bucket='', cache_images=True, cfg='/app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4l.yaml', data='/app/_data/ScaledYOLOv4/data/DataFile/data.yaml', device='', epochs=150, evolve=False, global_rank=-1, hyp='data/hyp.finetune.yaml', img_size=[1024, 1024], local_rank=-1, logdir='runs/', multi_scale=False, name='yolov4lp7_comp_2_42', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=6, weights='/app/_data/ScaledYOLOv4/weights/yolov4-p7.pt', world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# Hyperparameters {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.5, 'scale': 0.8, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mixup': 0.2}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1160  models.common.Conv                      [3, 40, 3, 1]
#   1                -1  1     28960  models.common.Conv                      [40, 80, 3, 2]
#   2                -1  1     30960  models.common.BottleneckCSP             [80, 80, 1]
#   3                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   4                -1  1    251360  models.common.BottleneckCSP             [160, 160, 3]
#   5                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   6                -1  1   4081600  models.common.BottleneckCSP             [320, 320, 15]
#   7                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   8                -1  1  16304000  models.common.BottleneckCSP             [640, 640, 15]
#   9                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#  10                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  11                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  12                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  13                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  14                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  15                -1  1  11888640  models.common.SPPCSP                    [1280, 640, 1]
#  16                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18                -6  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  19          [-1, -2]  1         0  models.common.Concat                    [1]
#  20                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  21                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  22                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  23               -13  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  24          [-1, -2]  1         0  models.common.Concat                    [1]
#  25                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  26                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  27                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  28               -20  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  29          [-1, -2]  1         0  models.common.Concat                    [1]
#  30                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  31                -1  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  32                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  33               -27  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  34          [-1, -2]  1         0  models.common.Concat                    [1]
#  35                -1  1    899200  models.common.BottleneckCSP2            [320, 160, 3]
#  36                -1  1    461440  models.common.Conv                      [160, 320, 3, 1]
#  37                -2  1    461440  models.common.Conv                      [160, 320, 3, 2]
#  38          [-1, 30]  1         0  models.common.Concat                    [1]
#  39                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  40                -1  1   1844480  models.common.Conv                      [320, 640, 3, 1]
#  41                -2  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#  42          [-1, 25]  1         0  models.common.Concat                    [1]
#  43                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  44                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  45                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  46          [-1, 20]  1         0  models.common.Concat                    [1]
#  47                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  48                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  49                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  50          [-1, 15]  1         0  models.common.Concat                    [1]
#  51                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  52                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  53[36, 40, 44, 48, 52]  1    115320  models.yolo.Detect                      [1, [[13, 17, 22, 25, 27, 66, 55, 41], [57, 88, 112, 69, 69, 177, 136, 138], [136, 138, 287, 114, 134, 275, 268, 248], [268, 248, 232, 504, 445, 416, 640, 640], [812, 393, 477, 808, 1070, 908, 1408, 1408]], [320, 640, 1280, 1280, 1280]]
# Model Summary: 722 layers, 2.86057e+08 parameters, 2.86057e+08 gradients
#
# Transferred 1417/1429 items from /app/_data/ScaledYOLOv4/weights/yolov4-p7.pt
# Optimizer groups: 240 .bias, 247 conv.weight, 235 other
# Scanning images: 100%|████████████████████| 4824/4824 [00:00<00:00, 7847.62it/s]
# Scanning labels /app/_data/yolo5_dataset.cache (3435 found, 0 missing, 1389 empt
# Caching images (13.0GB): 100%|██████████████| 4824/4824 [07:20<00:00, 10.94it/s]
# Scanning images: 100%|████████████████████| 1206/1206 [00:00<00:00, 7828.32it/s]
# Scanning labels /app/_data/yolo5_dataset.cache (859 found, 0 missing, 347 empty,
# Caching images (3.3GB): 100%|███████████████| 1206/1206 [03:10<00:00,  6.34it/s]
#
# Analyzing anchors... anchors/target = 11.65, Best Possible Recall (BPR) = 1.0000
# Image sizes 1024 train, 1024 test
# Using 6 dataloader workers
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      0/149     23.4G   0.07102    0.0344         0    0.1054        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.169       0.601       0.336      0.0862
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      1/149     23.4G    0.0565   0.02729         0   0.08379         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.314       0.471       0.374      0.0898
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      2/149     23.4G   0.05538   0.02662         0   0.08201        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.274        0.56       0.387       0.101
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      3/149     23.4G   0.05359   0.02619         0   0.07977        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.295       0.571        0.41       0.107
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      4/149     23.4G   0.05289   0.02594         0   0.07883         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.362       0.462       0.365      0.0952
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      5/149     23.4G   0.05206   0.02597         0   0.07804        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03        0.27        0.47       0.299      0.0811
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      6/149     23.4G   0.05175   0.02559         0   0.07734        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03        0.32       0.554       0.419       0.119
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      7/149     23.4G   0.05088   0.02624         0   0.07712        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.338        0.43       0.339      0.0882
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      8/149     23.4G   0.05126    0.0256         0   0.07686        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.385        0.51       0.419       0.111
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      9/149     23.4G    0.0511    0.0255         0    0.0766        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.341       0.574       0.465       0.134
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     10/149     23.4G   0.05069   0.02581         0    0.0765        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.308       0.562       0.407       0.101
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     11/149     23.4G   0.05045   0.02565         0   0.07611         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03        0.35         0.6       0.466       0.133
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     12/149     23.4G   0.04983    0.0253         0   0.07513        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03        0.34       0.594       0.465       0.141
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     13/149     23.4G      0.05   0.02557         0   0.07556        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.378       0.483       0.393       0.106
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     14/149     23.4G   0.04967   0.02539         0   0.07506        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.363       0.552       0.444       0.122
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     15/149     23.4G   0.04936   0.02517         0   0.07453        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.337       0.581       0.455        0.13
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     16/149     23.4G   0.04977   0.02479         0   0.07456        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03        0.31       0.603       0.465       0.125
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     17/149     23.4G   0.04921   0.02513         0   0.07434        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.373       0.547       0.454       0.114
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     18/149     23.4G   0.04931   0.02555         0   0.07486        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.338       0.594       0.471       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     19/149     23.4G   0.04898   0.02505         0   0.07403         5      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.359       0.603       0.477       0.143
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     20/149     23.4G   0.04868   0.02482         0    0.0735        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.367       0.575       0.465        0.14
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     21/149     23.4G   0.04908   0.02551         0    0.0746        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.379       0.608       0.504       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     22/149     23.4G   0.04878   0.02534         0   0.07412        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.394       0.553        0.48       0.133
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     23/149     23.4G   0.04891   0.02475         0   0.07365        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.363       0.569       0.467       0.123
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     24/149     23.4G    0.0482   0.02507         0   0.07327         7      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.393       0.607       0.499       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     25/149     23.4G   0.04822   0.02495         0   0.07316        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.354       0.601       0.484       0.133
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     26/149     23.4G   0.04841   0.02504         0   0.07345        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.363       0.615       0.493       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     27/149     23.4G   0.04784   0.02454         0   0.07238        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.365       0.626       0.505       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     28/149     23.4G   0.04837   0.02485         0   0.07322        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.342       0.647       0.508       0.146
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     29/149     23.4G   0.04792   0.02509         0   0.07302        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.361       0.577       0.453        0.13
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     30/149     23.4G   0.04812   0.02506         0   0.07318        27      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.307       0.619       0.481       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     31/149     23.4G   0.04777   0.02496         0   0.07273         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.395       0.592       0.497       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     32/149     23.4G   0.04762   0.02509         0   0.07271        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.338       0.618       0.488       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     33/149     23.4G   0.04765   0.02506         0   0.07271        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.366        0.56       0.453       0.128
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     34/149     23.4G    0.0472    0.0244         0    0.0716        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.372       0.565       0.464       0.137
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     35/149     23.4G   0.04797   0.02454         0   0.07251        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.333       0.583        0.46       0.127
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     36/149     23.4G   0.04723   0.02476         0   0.07199        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.355       0.625       0.511       0.155
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     37/149     23.4G   0.04727   0.02464         0   0.07191        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.349       0.588       0.472       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     38/149     23.4G   0.04702   0.02457         0   0.07159        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.308       0.625       0.462        0.14
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     39/149     23.4G   0.04711   0.02441         0   0.07152        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.393       0.592       0.486       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     40/149     23.4G   0.04668   0.02439         0   0.07107         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.361       0.629       0.499       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     41/149     23.4G   0.04701   0.02498         0   0.07199        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.405       0.508       0.431       0.117
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     42/149     23.4G   0.04681   0.02378         0    0.0706        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.403       0.581       0.484       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     43/149     23.4G    0.0469   0.02454         0   0.07144        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.387       0.567       0.465       0.136
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     44/149     23.4G   0.04627   0.02413         0    0.0704        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.375       0.617         0.5       0.145
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     45/149     23.4G   0.04637   0.02364         0   0.07001        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.401       0.577       0.494       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     46/149     23.4G   0.04603   0.02415         0   0.07018        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.354       0.634        0.51       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     47/149     23.4G   0.04651    0.0246         0   0.07111         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.359       0.616       0.498       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     48/149     23.4G   0.04612   0.02403         0   0.07016        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.363       0.594       0.478       0.143
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     49/149     23.4G   0.04603   0.02472         0   0.07075        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.325        0.63       0.485       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     50/149     23.4G   0.04654   0.02433         0   0.07086        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.343       0.613       0.489       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     51/149     23.4G   0.04529   0.02467         0   0.06996        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.381       0.608       0.498       0.148
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     52/149     23.4G   0.04575   0.02439         0   0.07014         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.362       0.597       0.484       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     53/149     23.4G   0.04561   0.02441         0   0.07002        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.347       0.626       0.497       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     54/149     23.4G   0.04561   0.02438         0   0.06999        24      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.414       0.569       0.477       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     55/149     23.4G   0.04588    0.0239         0   0.06977        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.388       0.596       0.493       0.148
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     56/149     23.4G   0.04581   0.02424         0   0.07005        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.368       0.619       0.506       0.156
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     57/149     23.4G    0.0454   0.02403         0   0.06943        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.362       0.621       0.488       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     58/149     23.4G   0.04524   0.02426         0    0.0695        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.382       0.611       0.501       0.155
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     59/149     23.4G   0.04536    0.0241         0   0.06946        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.365       0.618        0.48       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     60/149     23.4G   0.04504     0.024         0   0.06904        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.375       0.596        0.48       0.148
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     61/149     23.4G   0.04481    0.0242         0   0.06901         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.403       0.595       0.503       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     62/149     23.4G   0.04478    0.0241         0   0.06888        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.369       0.611       0.503        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     63/149     23.4G    0.0451   0.02381         0   0.06891        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.351       0.608       0.475       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     64/149     23.4G   0.04468   0.02404         0   0.06871        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03       0.361       0.621       0.494       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     65/149     23.4G    0.0446   0.02377         0   0.06837        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.59e+03        0.37       0.593       0.474       0.145
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     66/149     23.4G   0.04425   0.02367         0   0.06792        17      1024
