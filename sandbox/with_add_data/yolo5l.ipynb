# %%
import ast
import os
import shutil

import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import Image, clear_output
from sklearn.model_selection import StratifiedKFold, train_test_split
from tqdm import tqdm
InteractiveShell.ast_node_interactivity = "all"

# %%
# shutil.rmtree('/app/_data/jpg_transformed')

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# clear_output()

# %%
os.chdir("/app/_data/yolov5")

# %%
# !pip install -r requirements.txt
clear_output()

# %%
# df = pd.read_csv("/app/_data/transformed_bboxes_df.csv")
df = pd.read_csv("/app/_data/bboxes.csv")
labels = pd.read_csv('/app/_data/additional_dataset/labels_full.csv')

# %%
labels['Target'].value_counts()
labels[(labels['Target']==0)&(labels['x_center']).isna()].shape
# Out:
# 0    20672
# 1     9555
# Name: Target, dtype: int64
# (20672, 17)

# %%
labels['img'] = labels['patientId']
labels['bbox'] = labels['Target']
labels['width'] = labels['w']
labels['height'] = labels['h']
labels['label'] = labels['bbox'].replace({0:'negative', 1:'positive'})
labels = labels[df.columns[1:]]
labels.head()
# Out:
#                                     img     label  bbox  x_center  y_center  \
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6  negative     0       NaN       NaN
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd  negative     0       NaN       NaN
# 2  00322d4d-1c29-4943-afc9-b6754be640eb  negative     0       NaN       NaN
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5  negative     0       NaN       NaN
# 4  00436515-870c-4b36-a041-de91049b9ab4  positive     1  0.361816  0.333496
#
#       width    height  class
# 0       NaN       NaN      0
# 1       NaN       NaN      0
# 2       NaN       NaN      0
# 3       NaN       NaN      0
# 4  0.208008  0.370117      0

# %%
labels_1 = labels.query('bbox==1')
labels_0 = labels.query('bbox==0').sample(1000)

# %%
df = pd.concat([df[df.columns[1:]], labels_1, labels_0], axis=0, ignore_index=True).sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.shape
# Out:
# (20144, 8)

# %%
base_config = {
    "IMG_HEIGH": 640,
    "IMG_WIDTH": 640,
    "BATCH_SIZE": 20,
    "SEED": 1488,
}

# %%
groupped_data =pd.pivot_table(df,index='img', values=['label', 'bbox'],aggfunc='first')
groupped_data['img'] = groupped_data.index.tolist()
groupped_data = groupped_data.reset_index(drop=True)

# %%
groupped_data
# Out:
#        bbox     label                                   img
# 0         0  negative  0004cfab-14fd-4e49-80ba-63a80b6bddd6
# 1         1   typical                          000a312787f2
# 2         0  negative                          000c3a3f293f
# 3         1  positive  000db696-cf54-4385-b10b-6b16fbb3f985
# 4         1  positive  000fe35a-2649-43d4-b027-e67796d412e0
# ...     ...       ...                                   ...
# 13037     1   typical                          ffd9b6cf2961
# 13038     1   typical                          ffdc682f7680
# 13039     1   typical                          ffe942c8655f
# 13040     1  positive  fff0b503-72a5-446a-843d-f3d152e39053
# 13041     1  positive  fffb2395-8edd-4954-8a89-ffe2fd329be3
#
# [13042 rows x 3 columns]

# %%
groupped_data['bbox'].value_counts()
# Out:
# 1    10306
# 0     2736
# Name: bbox, dtype: int64

# %%
skf = StratifiedKFold(n_splits=5, random_state=base_config["SEED"], shuffle=True)
train_ids = []
val_ids = []
for train_index, valid_index in skf.split(groupped_data, groupped_data['label']):
    train_ids.append(train_index)
    val_ids.append(valid_index)

# %%
m=0
train_imgs = groupped_data.loc[train_ids[m]]['img'].tolist()
val_imgs = groupped_data.loc[val_ids[m]]['img'].tolist()

# %%
def make_yolo_dataset(df, train_imgs, val_imgs, fold_name):
    path = "/app/_data/yolo5_dataset/" + fold_name
    img_path = os.path.join(path, "images")
    labels_path = os.path.join(path, "labels")
    for dir_name in ["train", "val"]:
        os.makedirs(os.path.join(img_path, dir_name))
        os.makedirs(os.path.join(labels_path, dir_name))
    for img_name in tqdm(df['img'].unique().tolist()):
        new_df = df[df['img']==img_name].reset_index(drop=True)
        if img_name in train_imgs:
            dir_name = "train"
        elif img_name in val_imgs:
            dir_name = "val"
        shutil.copy(
            "/app/_data/jpg/" + img_name + ".jpg",
            os.path.join(img_path, dir_name, img_name + ".jpg"),
        )
        if new_df.loc[0,'bbox']==1:
            boxes = new_df[['class', 'x_center','y_center','width','height']].values
            list_boxes = []
            for box in boxes:
                list_boxes.append(
                    [
                        str(box[0]),
                        str(box[1]),
                        str(box[2]),
                        str(box[3]),
                        str(box[4]),
                    ]
                )
            with open(os.path.join(labels_path, dir_name, img_name + ".txt"), "w") as f:
                for j in range(len(list_boxes)):
                    text = " ".join(list_boxes[j])
                    f.write(text)
                    f.write("\n")

# %%
# shutil.rmtree('/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/')

# %%
make_yolo_dataset(df, train_imgs, val_imgs, "yolo5l6_skf_voi_1")
# Out:
# 100%|██████████| 13042/13042 [00:59<00:00, 218.86it/s]

# %%
len(os.listdir("/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/labels/train"))
len(os.listdir("/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/images/train"))
len(os.listdir("/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/labels/val"))
len(os.listdir("/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/images/val"))
# Out:
# 8245
# 10433
# 2061
# 2609

# %%
# customize iPython writefile so we can write variables

from IPython.core.magic import register_line_cell_magic


@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, "w") as f:
        f.write(cell.format(**globals()))

# %%
if not os.path.exists("/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile"):
    os.mkdir("/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile")

# %%
# %%writetemplate /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile/data.yaml
# # train and val data
# train: /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/images/train
# val: /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/images/val
# # number of classes
# nc: 1
# # class names
# names: ["opacity"]

# %%
# %%writetemplate /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile/customYOLOv5l6.yaml
# # parameters
# nc: 1  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [ 19,27,  44,40,  38,94 ]  # P3/8
#   - [ 96,68,  86,152,  180,137 ]  # P4/16
#   - [ 140,301,  303,264,  238,542 ]  # P5/32
#   - [ 436,615,  739,380,  925,792 ]  # P6/64
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [ [ -1, 1, Focus, [ 64, 3 ] ],  # 0-P1/2
#     [ -1, 1, Conv, [ 128, 3, 2 ] ],  # 1-P2/4
#     [ -1, 3, C3, [ 128 ] ],
#     [ -1, 1, Conv, [ 256, 3, 2 ] ],  # 3-P3/8
#     [ -1, 9, C3, [ 256 ] ],
#     [ -1, 1, Conv, [ 512, 3, 2 ] ],  # 5-P4/16
#     [ -1, 9, C3, [ 512 ] ],
#     [ -1, 1, Conv, [ 768, 3, 2 ] ],  # 7-P5/32
#     [ -1, 3, C3, [ 768 ] ],
#     [ -1, 1, Conv, [ 1024, 3, 2 ] ],  # 9-P6/64
#     [ -1, 1, SPP, [ 1024, [ 3, 5, 7 ] ] ],
#     [ -1, 3, C3, [ 1024, False ] ],  # 11
#   ]
#
# # YOLOv5 head
# head:
#   [ [ -1, 1, Conv, [ 768, 1, 1 ] ],
#     [ -1, 1, nn.Upsample, [ None, 2, 'nearest' ] ],
#     [ [ -1, 8 ], 1, Concat, [ 1 ] ],  # cat backbone P5
#     [ -1, 3, C3, [ 768, False ] ],  # 15
#
#     [ -1, 1, Conv, [ 512, 1, 1 ] ],
#     [ -1, 1, nn.Upsample, [ None, 2, 'nearest' ] ],
#     [ [ -1, 6 ], 1, Concat, [ 1 ] ],  # cat backbone P4
#     [ -1, 3, C3, [ 512, False ] ],  # 19
#
#     [ -1, 1, Conv, [ 256, 1, 1 ] ],
#     [ -1, 1, nn.Upsample, [ None, 2, 'nearest' ] ],
#     [ [ -1, 4 ], 1, Concat, [ 1 ] ],  # cat backbone P3
#     [ -1, 3, C3, [ 256, False ] ],  # 23 (P3/8-small)
#
#     [ -1, 1, Conv, [ 256, 3, 2 ] ],
#     [ [ -1, 20 ], 1, Concat, [ 1 ] ],  # cat head P4
#     [ -1, 3, C3, [ 512, False ] ],  # 26 (P4/16-medium)
#
#     [ -1, 1, Conv, [ 512, 3, 2 ] ],
#     [ [ -1, 16 ], 1, Concat, [ 1 ] ],  # cat head P5
#     [ -1, 3, C3, [ 768, False ] ],  # 29 (P5/32-large)
#
#     [ -1, 1, Conv, [ 768, 3, 2 ] ],
#     [ [ -1, 12 ], 1, Concat, [ 1 ] ],  # cat head P6
#     [ -1, 3, C3, [ 1024, False ] ],  # 32 (P6/64-xlarge)
#
#     [ [ 23, 26, 29, 32 ], 1, Detect, [ nc, anchors ] ],  # Detect(P3, P4, P5, P6)
#   ]

# %%
# if os.path.exists('/app/_data/yolov5/runs/train/yolov5l6_voi_0'):
#     shutil.rmtree('/app/_data/yolov5/runs/train/yolov5l6_voi_0')

# %%
# %%time
# !python train.py --img 640 \
                 --batch 20 \
                 --epochs 150 \
                 --data /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile/data.yaml \
                 --cfg /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile/customYOLOv5l6.yaml \
                 --weights yolov5l6.pt  \
                 --name yolov5l6_voi_1 --cache
# Out:
# github: skipping check (Docker image), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v5.0-150-gabb2a96 torch 1.8.1+cu111 CUDA:0 (NVIDIA GeForce RTX 3090, 24268.3125MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=20, bbox_interval=-1, bucket='', cache_images=True, cfg='/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile/customYOLOv5l6.yaml', data='/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/DataFile/data.yaml', device='', entity=None, epochs=150, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov5l6_voi_1', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov5l6_voi_1', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=20, upload_dataset=False, weights='yolov5l6.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0
# wandb: Install Weights & Biases for YOLOv5 logging with 'pip install wandb' (recommended)
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Focus                     [3, 64, 3]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  1   1611264  models.common.C3                        [256, 256, 9]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  1   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   3540480  models.common.Conv                      [512, 768, 3, 2]
#   8                -1  1   5611008  models.common.C3                        [768, 768, 3]
#   9                -1  1   7079936  models.common.Conv                      [768, 1024, 3, 2]
#  10                -1  1   2624512  models.common.SPP                       [1024, 1024, [3, 5, 7]]
#  11                -1  1   9971712  models.common.C3                        [1024, 1024, 3, False]
#  12                -1  1    787968  models.common.Conv                      [1024, 768, 1, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 8]  1         0  models.common.Concat                    [1]
#  15                -1  1   6200832  models.common.C3                        [1536, 768, 3, False]
#  16                -1  1    394240  models.common.Conv                      [768, 512, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18           [-1, 6]  1         0  models.common.Concat                    [1]
#  19                -1  1   2757632  models.common.C3                        [1024, 512, 3, False]
#  20                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  21                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  22           [-1, 4]  1         0  models.common.Concat                    [1]
#  23                -1  1    690688  models.common.C3                        [512, 256, 3, False]
#  24                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  25          [-1, 20]  1         0  models.common.Concat                    [1]
#  26                -1  1   2495488  models.common.C3                        [512, 512, 3, False]
#  27                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  28          [-1, 16]  1         0  models.common.Concat                    [1]
#  29                -1  1   5807616  models.common.C3                        [1024, 768, 3, False]
#  30                -1  1   5309952  models.common.Conv                      [768, 768, 3, 2]
#  31          [-1, 12]  1         0  models.common.Concat                    [1]
#  32                -1  1  10496000  models.common.C3                        [1536, 1024, 3, False]
#  33  [23, 26, 29, 32]  1     46152  models.yolo.Detect                      [1, [[19, 27, 44, 40, 38, 94], [96, 68, 86, 152, 180, 137], [140, 301, 303, 264, 238, 542], [436, 615, 739, 380, 925, 792]], [256, 512, 768, 1024]]
# Model Summary: 638 layers, 76655560 parameters, 76655560 gradients, 116.5 GFLOPs
#
# Transferred 822/832 items from yolov5l6.pt
# Scaled weight_decay = 0.00046875
# Optimizer groups: 141 .bias, 141 conv.weight, 137 other
# train: Scanning '/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/labels/train' images
# train: New cache created: /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/labels/train.cache
# train: Caching images (12.0GB): 100%|████| 10433/10433 [01:17<00:00, 134.53it/s]
# val: Scanning '/app/_data/yolo5_dataset/yolo5l6_skf_voi_1/labels/val' images and
# val: New cache created: /app/_data/yolo5_dataset/yolo5l6_skf_voi_1/labels/val.cache
# val: Caching images (3.0GB): 100%|██████████| 2609/2609 [00:31<00:00, 83.69it/s]
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 7.08, Best Possible Recall (BPR) = 1.0000
# Image sizes 640 train, 640 test
# Using 8 dataloader workers
# Logging results to runs/train/yolov5l6_voi_1
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      0/149       19G   0.06396   0.02455         0   0.08851        30       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.443      0.402      0.329     0.0867
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      1/149     18.9G   0.04924   0.02039         0   0.06962        28       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.482      0.496      0.429      0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      2/149     18.9G   0.04755   0.01947         0   0.06702        27       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.385      0.373      0.256     0.0697
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      3/149     18.9G   0.04677   0.01959         0   0.06636        25       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.452      0.487      0.402      0.112
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      4/149     18.9G   0.04538   0.01967         0   0.06505        28       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.515      0.499      0.454      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      5/149     18.9G   0.04485   0.01927         0   0.06412        29       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.491      0.516      0.441      0.138
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      6/149     18.9G   0.04428   0.01927         0   0.06355        33       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.478      0.469      0.381      0.106
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      7/149     18.9G   0.04372   0.01905         0   0.06277        23       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0
640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.525      0.527      0.454      0.136
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    111/149     18.9G    0.0219   0.01164         0   0.03354        22       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.531      0.519      0.453      0.136
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    112/149     18.9G   0.02183    0.0118         0   0.03363        39       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.531      0.518       0.45      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    113/149     18.9G   0.02166   0.01178         0   0.03344        40       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.531      0.517      0.451      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    114/149     18.9G   0.02154   0.01152         0   0.03306        39       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.532      0.515       0.45      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    115/149     18.9G   0.02132   0.01148         0    0.0328        35       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462       0.54      0.508      0.451      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    116/149     18.9G   0.02103   0.01139         0   0.03242        33       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.538       0.51      0.451      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    117/149     18.9G   0.02063   0.01137         0     0.032        30       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.539      0.507       0.45      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    118/149     18.9G   0.02061    0.0113         0   0.03191        39       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.541      0.508       0.45      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    119/149     18.9G   0.02042    0.0112         0   0.03162        25       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.538       0.51       0.45      0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    120/149     18.9G   0.02016   0.01101         0   0.03116        31       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.515      0.529      0.448      0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    121/149     18.9G   0.01986   0.01079         0   0.03065        32       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.538      0.509      0.448      0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    122/149     18.9G   0.01962   0.01083         0   0.03046        25       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.536      0.508      0.447      0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    123/149     18.9G   0.01966   0.01082         0   0.03047        29       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.535      0.511      0.448      0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    124/149     18.9G   0.01928   0.01066         0   0.02993        22       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.535       0.51      0.447      0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    125/149     18.9G   0.01921   0.01067         0   0.02989        37       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.534      0.508      0.446      0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    126/149     18.9G   0.01899   0.01055         0   0.02954        25       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.538      0.505      0.444      0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    127/149     18.9G   0.01876   0.01049         0   0.02925        25       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.519       0.52      0.443      0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    128/149     18.9G   0.01858   0.01038         0   0.02896        36       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.517      0.523      0.443      0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    129/149     18.9G   0.01841   0.01025         0   0.02866        32       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.517      0.521      0.442      0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    130/149     18.9G   0.01829   0.01016         0   0.02845        29       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.516      0.523      0.443      0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    131/149     18.9G   0.01794   0.01021         0   0.02815        25       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.517      0.522      0.442      0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    132/149     18.9G     0.018   0.01001         0   0.02801        25       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.532      0.506       0.44      0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    133/149     18.9G   0.01784      0.01         0   0.02785        35       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462       0.53      0.507      0.439      0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    134/149     18.9G   0.01777  0.009972         0   0.02775        46       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.526      0.508      0.439      0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    135/149     18.9G   0.01759  0.009864         0   0.02745        36       640
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all       2609       3462      0.524       0.51      0.439      0.131
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    136/149     18.9G   0.01752   0.00982         0   0.02734        53       640

# %%
# shutil.rmtree('/app/_data/yolov5/runs/train/yolov5x_trans_0')

# %%
Image("./runs/train/Result15/results.png")

# %%
Image("/app/_data/Yolov5/yolov5/runs/train/Result15/confusion_matrix.png", width=600)

# %%
# !python detect.py --img-size 640  --conf 0.3 --source /app/_data/yolo5_dataset/tr_test_42/images/val/ --weights /app/_data/Yolov5/yolov5/runs/train/Result15/weights/best.pt --augment --save-txt --save-conf

# %%
Image("/app/_data/Yolov5/yolov5/runs/detect/exp/ffdc682f7680.jpg")

# %%
for i in os.listdir("/app/_data/Yolov5/yolov5/runs/detect/exp2/labels/"):
    if ".jpg" not in i:
        print(i)

# %%
# !pip uninstall wandb
clear_output()
