# %%
import ast
import os
import shutil
import torch
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import Image, clear_output
from sklearn.model_selection import StratifiedKFold, train_test_split
from tqdm import tqdm
InteractiveShell.ast_node_interactivity = "all"

# %%
# !git clone https://github.com/WongKinYiu/ScaledYOLOv4.git
# !git clone https://github.com/thomasbrandon/mish-cuda
# %cd /app/_data/ScaledYOLOv4/mish-cuda
# !python setup.py build install
clear_output()
# %cd /app/_data/ScaledYOLOv4
! git checkout yolov4-large
# Out:
# /app/_data/ScaledYOLOv4
# M	detect.py
# M	utils/general.py
# Already on 'yolov4-large'
# Your branch is up to date with 'origin/yolov4-large'.

# %% [markdown]
# ## preparing data

# %%
df = pd.read_csv("/app/_data/bboxes.csv")
df['path'] = '/app/_data/yolo5_dataset/'+df['img']+'.jpg'
base_config = {
    "IMG_SIZE": 1024,
    "BATCH_SIZE": 10,
    "SEED": 42,
}

# %%
df
# Out:
#              study           img     label  bbox  x_center  y_center  \
# 0     5776db0cec75  000a312787f2   typical     1  0.306066  0.441824
# 1     5776db0cec75  000a312787f2   typical     1  0.656307  0.422013
# 2     ff0879eb20ed  000c3a3f293f  negative     0       NaN       NaN
# 3     9d514ce429a7  0012ff7358bc   typical     1  0.363652  0.274319
# 4     9d514ce429a7  0012ff7358bc   typical     1  0.687567  0.394942
# ...            ...           ...       ...   ...       ...       ...
# 9584  7eed9af03814  ffd9b6cf2961   typical     1  0.296171  0.480181
# 9585  a0cb0b96fb3d  ffdc682f7680   typical     1  0.817057  0.468622
# 9586  a0cb0b96fb3d  ffdc682f7680   typical     1  0.314128  0.565537
# 9587  7d82d53204b8  ffe942c8655f   typical     1  0.313157  0.355756
# 9588  7d82d53204b8  ffe942c8655f   typical     1  0.698962  0.366852
#
#          width    height  class                                       path
# 0     0.241226  0.549685      0  /app/_data/yolo5_dataset/000a312787f2.jpg
# 1     0.257204  0.505031      0  /app/_data/yolo5_dataset/000a312787f2.jpg
# 2          NaN       NaN      0  /app/_data/yolo5_dataset/000c3a3f293f.jpg
# 3     0.283965  0.392996      0  /app/_data/yolo5_dataset/0012ff7358bc.jpg
# 4     0.201907  0.473411      0  /app/_data/yolo5_dataset/0012ff7358bc.jpg
# ...        ...       ...    ...                                        ...
# 9584  0.128571  0.355606      0  /app/_data/yolo5_dataset/ffd9b6cf2961.jpg
# 9585  0.351563  0.746727      0  /app/_data/yolo5_dataset/ffdc682f7680.jpg
# 9586  0.155599  0.222429      0  /app/_data/yolo5_dataset/ffdc682f7680.jpg
# 9587  0.325139  0.550925      0  /app/_data/yolo5_dataset/ffe942c8655f.jpg
# 9588  0.308485  0.480492      0  /app/_data/yolo5_dataset/ffe942c8655f.jpg
#
# [9589 rows x 10 columns]

# %%
groupped_data =pd.pivot_table(df,index='img', values=['label', 'bbox', 'path'],aggfunc='first')
groupped_data['img'] = groupped_data.index
groupped_data = groupped_data.reset_index(drop=True)
groupped_data.head()
groupped_data['bbox'].value_counts()
# Out:
#    bbox     label                                       path           img
# 0     1   typical  /app/_data/yolo5_dataset/000a312787f2.jpg  000a312787f2
# 1     0  negative  /app/_data/yolo5_dataset/000c3a3f293f.jpg  000c3a3f293f
# 2     1   typical  /app/_data/yolo5_dataset/0012ff7358bc.jpg  0012ff7358bc
# 3     1  atypical  /app/_data/yolo5_dataset/001398f4ff4f.jpg  001398f4ff4f
# 4     1   typical  /app/_data/yolo5_dataset/001bd15d1891.jpg  001bd15d1891
# 1    4294
# 0    1736
# Name: bbox, dtype: int64

# %%
skf = StratifiedKFold(n_splits=5, random_state=base_config["SEED"], shuffle=True)
train_ids = []
val_ids = []
for train_index, valid_index in skf.split(groupped_data, groupped_data['label']):
    train_ids.append(train_index)
    val_ids.append(valid_index)

# %%
if not os.path.exists('/app/_data/yolo5_dataset/yolo4/'):
    os.mkdir('/app/_data/yolo5_dataset/yolo4/')
for i in range(5):
    train_img_path = groupped_data.loc[train_ids[i]]['path'].tolist()
    val_img_path = groupped_data.loc[val_ids[i]]['path'].tolist()
    np.savetxt("/app/_data/yolo5_dataset/yolo4/train_"+str(i)+".txt", train_img_path, fmt='%s')
    np.savetxt("/app/_data/yolo5_dataset/yolo4/val_"+str(i)+".txt", val_img_path, fmt='%s')

# %%
for img_name in tqdm(df['img'].unique().tolist()):
    new_df = df[df['img']==img_name].reset_index(drop=True)
    if new_df.loc[0,'bbox']==1:
        boxes = new_df[['class', 'x_center','y_center','width','height']].values
        list_boxes = []
        for box in boxes:
            list_boxes.append(
                [
                    str(box[0]),
                    str(box[1]),
                    str(box[2]),
                    str(box[3]),
                    str(box[4]),
                ]
            )
        np.savetxt("/app/_data/yolo5_dataset/yolo4/"+img_name+".txt", list_boxes, fmt='%s')
clear_output()

# %% [markdown]
# ## Writing data.yaml and custom parameters yolov4-p7

# %%
# customize iPython writefile so we can write variables

from IPython.core.magic import register_line_cell_magic


@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, "w") as f:
        f.write(cell.format(**globals()))

# %%
if not os.path.exists("/app/_data/ScaledYOLOv4/data/DataFile"):
    os.mkdir("/app/_data/ScaledYOLOv4/data/DataFile")

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/data.yaml
# # train and val datasets (image directory or *.txt file with image paths)
# train: /app/_data/yolo5_dataset/yolo4/train_3.txt
# val: /app/_data/yolo5_dataset/yolo4/val_3.txt
# # number of classes
# nc: 1
# # class names
# names: ['opacity']

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml
# # parameters yolov4-p7
# nc: 1  # number of classes
# depth_multiple: 1.0  # expand model depth
# width_multiple: 1.25  # expand layer channels
#
# # anchors
# anchors:
#   - [13,17,  22,25,  27,66,  55,41]  # P3/8
#   - [57,88,  112,69,  69,177,  136,138]  # P4/16
#   - [136,138,  287,114,  134,275,  268,248]  # P5/32
#   - [268,248,  232,504,  445,416,  640,640]  # P6/64
#   - [812,393,  477,808,  1070,908,  1408,1408]  # P7/128
#
# # csp-p7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, BottleneckCSP, [64]],
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 5-P3/8
#    [-1, 15, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 7-P4/16
#    [-1, 15, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]], # 9-P5/32
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 11-P6/64
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 13-P7/128
#    [-1, 7, BottleneckCSP, [1024]],  # 14
#   ]
#
# # yolov4-p7 head
# # na = len(anchors[0])
# head:
#   [[-1, 1, SPPCSP, [512]], # 15
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-6, 1, Conv, [512, 1, 1]], # route backbone P6
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 20
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-13, 1, Conv, [512, 1, 1]], # route backbone P5
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 25
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-20, 1, Conv, [256, 1, 1]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [256]], # 30
#    [-1, 1, Conv, [128, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-27, 1, Conv, [128, 1, 1]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [128]], # 35
#    [-1, 1, Conv, [256, 3, 1]],
#    [-2, 1, Conv, [256, 3, 2]],
#    [[-1, 30], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [256]], # 39
#    [-1, 1, Conv, [512, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 25], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 43
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 20], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 47
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 15], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 51
#    [-1, 1, Conv, [1024, 3, 1]],
#
#    [[36,40,44,48,52], 1, Detect, [nc, anchors]],   # Detect(P3, P4, P5, P6, P7)
#   ]

# %% [markdown]
# ## train

# %%
# !python train.py --img 1024 \
                 --batch 6 \
                 --epochs 150 \
                 --data /app/_data/ScaledYOLOv4/data/DataFile/data.yaml \
                 --cfg /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml \
                 --weights /app/_data/ScaledYOLOv4/weights/yolov4-p7.pt \
                 --name yolov4lp7_comp_3_42_1cl \
                 --cache
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090', total_memory=24268MB)
#
# Namespace(adam=False, batch_size=6, bucket='', cache_images=True, cfg='/app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml', data='/app/_data/ScaledYOLOv4/data/DataFile/data.yaml', device='', epochs=150, evolve=False, global_rank=-1, hyp='data/hyp.finetune.yaml', img_size=[1024, 1024], local_rank=-1, logdir='runs/', multi_scale=False, name='yolov4lp7_comp_3_42_1cl', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=6, weights='/app/_data/ScaledYOLOv4/weights/yolov4-p7.pt', world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# Hyperparameters {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.5, 'scale': 0.8, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mixup': 0.2}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1160  models.common.Conv                      [3, 40, 3, 1]
#   1                -1  1     28960  models.common.Conv                      [40, 80, 3, 2]
#   2                -1  1     30960  models.common.BottleneckCSP             [80, 80, 1]
#   3                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   4                -1  1    251360  models.common.BottleneckCSP             [160, 160, 3]
#   5                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   6                -1  1   4081600  models.common.BottleneckCSP             [320, 320, 15]
#   7                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   8                -1  1  16304000  models.common.BottleneckCSP             [640, 640, 15]
#   9                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#  10                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  11                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  12                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  13                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  14                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  15                -1  1  11888640  models.common.SPPCSP                    [1280, 640, 1]
#  16                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18                -6  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  19          [-1, -2]  1         0  models.common.Concat                    [1]
#  20                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  21                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  22                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  23               -13  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  24          [-1, -2]  1         0  models.common.Concat                    [1]
#  25                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  26                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  27                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  28               -20  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  29          [-1, -2]  1         0  models.common.Concat                    [1]
#  30                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  31                -1  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  32                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  33               -27  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  34          [-1, -2]  1         0  models.common.Concat                    [1]
#  35                -1  1    899200  models.common.BottleneckCSP2            [320, 160, 3]
#  36                -1  1    461440  models.common.Conv                      [160, 320, 3, 1]
#  37                -2  1    461440  models.common.Conv                      [160, 320, 3, 2]
#  38          [-1, 30]  1         0  models.common.Concat                    [1]
#  39                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  40                -1  1   1844480  models.common.Conv                      [320, 640, 3, 1]
#  41                -2  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#  42          [-1, 25]  1         0  models.common.Concat                    [1]
#  43                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  44                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  45                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  46          [-1, 20]  1         0  models.common.Concat                    [1]
#  47                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  48                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  49                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  50          [-1, 15]  1         0  models.common.Concat                    [1]
#  51                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  52                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  53[36, 40, 44, 48, 52]  1    115320  models.yolo.Detect                      [1, [[13, 17, 22, 25, 27, 66, 55, 41], [57, 88, 112, 69, 69, 177, 136, 138], [136, 138, 287, 114, 134, 275, 268, 248], [268, 248, 232, 504, 445, 416, 640, 640], [812, 393, 477, 808, 1070, 908, 1408, 1408]], [320, 640, 1280, 1280, 1280]]
# Model Summary: 722 layers, 2.86057e+08 parameters, 2.86057e+08 gradients
#
# Transferred 1417/1429 items from /app/_data/ScaledYOLOv4/weights/yolov4-p7.pt
# Optimizer groups: 240 .bias, 247 conv.weight, 235 other
# Scanning images: 100%|████████████████████| 4824/4824 [00:00<00:00, 7393.07it/s]
# Scanning labels /app/_data/yolo5_dataset.cache (3435 found, 0 missing, 1389 empt
# Caching images (13.0GB): 100%|██████████████| 4824/4824 [07:18<00:00, 11.01it/s]
# Scanning images: 100%|████████████████████| 1206/1206 [00:00<00:00, 7488.17it/s]
# Scanning labels /app/_data/yolo5_dataset.cache (859 found, 0 missing, 347 empty,
# Caching images (3.3GB): 100%|███████████████| 1206/1206 [03:04<00:00,  6.53it/s]
#
# Analyzing anchors... anchors/target = 11.62, Best Possible Recall (BPR) = 1.0000
# Image sizes 1024 train, 1024 test
# Using 6 dataloader workers
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      0/149     23.4G    0.0714   0.03466         0    0.1061        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.291        0.53       0.358      0.0996
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      1/149     23.4G   0.05657   0.02774         0   0.08431         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.307       0.545       0.397       0.116
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      2/149     23.4G   0.05509    0.0271         0   0.08219        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.298       0.428       0.314       0.083
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      3/149     23.4G   0.05485   0.02606         0   0.08091        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.272       0.509       0.366      0.0974
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      4/149     23.4G   0.05313   0.02622         0   0.07936         6      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.402       0.562       0.467       0.129
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      5/149     23.4G   0.05224   0.02599         0   0.07822        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03         0.3       0.582       0.436       0.124
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      6/149     23.4G   0.05167   0.02578         0   0.07745        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.276       0.545       0.395       0.108
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      7/149     23.4G   0.05155   0.02624         0   0.07779        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.319       0.611       0.473       0.134
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      8/149     23.4G   0.05092     0.026         0   0.07692        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.39       0.571       0.483       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      9/149     23.4G   0.05125   0.02547         0   0.07672        24      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.307       0.616       0.464       0.136
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     10/149     23.4G   0.05041   0.02552         0   0.07592        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.313       0.627       0.477        0.14
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     11/149     23.4G   0.05038   0.02542         0   0.07581        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.306       0.362       0.281      0.0783
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     12/149     23.4G    0.0499    0.0253         0    0.0752        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.351        0.56       0.449       0.131
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     13/149     23.4G    0.0502   0.02579         0     0.076        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.363       0.592       0.472       0.143
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     14/149     23.4G    0.0498   0.02546         0   0.07526        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.388       0.598       0.491       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     15/149     23.4G    0.0498   0.02529         0   0.07509        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03         0.4       0.586       0.492       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     16/149     23.4G    0.0493   0.02484         0   0.07414        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.326       0.611       0.465       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     17/149     23.4G   0.04943   0.02498         0    0.0744        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.345       0.544       0.433       0.122
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     18/149     23.4G    0.0493   0.02531         0   0.07461        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03         0.3       0.632        0.48       0.136
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     19/149     23.4G   0.04882   0.02519         0   0.07401        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.344       0.607        0.47       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     20/149     23.4G   0.04907   0.02487         0   0.07394        26      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.354       0.628       0.499       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     21/149     23.4G   0.04905   0.02534         0    0.0744        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.39       0.597       0.481       0.146
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     22/149     23.4G   0.04846   0.02517         0   0.07362        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.323       0.523       0.385       0.103
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     23/149     23.4G   0.04853   0.02484         0   0.07337        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.37       0.462       0.369       0.097
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     24/149     23.4G   0.04848    0.0248         0   0.07328        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.307        0.65       0.512       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     25/149     23.4G   0.04836   0.02491         0   0.07327        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.39       0.601       0.499       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     26/149     23.4G   0.04827   0.02487         0   0.07315        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.332        0.66       0.516       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     27/149     23.4G   0.04811   0.02484         0   0.07296        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.351       0.609       0.462       0.141
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     28/149     23.4G   0.04814   0.02542         0   0.07356        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.371       0.638       0.527       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     29/149     23.4G    0.0481   0.02508         0   0.07317        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.29        0.64       0.463       0.136
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     30/149     23.4G     0.048   0.02515         0   0.07316        24      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.382       0.612       0.507       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     31/149     23.4G    0.0478   0.02508         0   0.07288        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.374       0.608       0.502        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     32/149     23.4G   0.04795   0.02488         0   0.07283        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.35        0.64       0.508       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     33/149     23.4G   0.04794    0.0247         0   0.07264        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.365        0.62       0.494       0.146
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     34/149     23.4G   0.04766   0.02458         0   0.07224        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.368       0.553       0.445       0.125
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     35/149     23.4G    0.0473   0.02497         0   0.07227        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.381       0.585       0.478       0.138
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     36/149     23.4G   0.04728   0.02479         0   0.07206        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.38       0.636       0.529       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     37/149     23.4G   0.04762   0.02509         0   0.07271        24      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.405       0.628       0.525       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     38/149     23.4G   0.04712   0.02457         0   0.07168        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.346       0.611       0.474       0.145
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     39/149     23.4G   0.04697   0.02487         0   0.07183        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.349       0.652       0.516       0.155
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     40/149     23.4G   0.04701   0.02438         0   0.07139        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.352        0.64        0.51        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     41/149     23.4G   0.04684   0.02493         0   0.07177        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.384        0.63       0.518       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     42/149     23.4G   0.04661   0.02407         0   0.07068        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.318        0.64       0.486       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     43/149     23.4G   0.04686   0.02417         0   0.07104        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.351        0.66       0.512       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     44/149     23.4G    0.0469   0.02441         0   0.07131        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.364       0.609       0.484       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     45/149     23.4G   0.04659   0.02452         0   0.07111        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.43       0.592       0.508       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     46/149     23.4G   0.04608   0.02407         0   0.07014        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.329       0.636       0.498       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     47/149     23.4G   0.04628   0.02442         0    0.0707        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.402       0.618       0.517       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     48/149     23.4G   0.04602   0.02438         0   0.07039        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.346       0.644        0.52       0.157
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     49/149     23.4G   0.04593    0.0247         0   0.07063        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.367       0.643       0.526       0.159
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     50/149     23.4G   0.04593   0.02409         0   0.07002        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.351       0.627       0.509        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     51/149     23.4G   0.04547   0.02441         0   0.06988        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.371       0.618       0.507       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     52/149     23.4G   0.04572   0.02432         0   0.07004         5      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.403       0.616       0.519       0.159
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     53/149     23.4G   0.04604    0.0244         0   0.07044        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.365       0.649       0.529       0.161
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     54/149     23.4G   0.04547   0.02444         0   0.06991        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.364       0.636       0.522       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     55/149     23.4G   0.04529    0.0241         0   0.06939        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.355       0.635       0.489       0.148
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     56/149     23.4G   0.04546   0.02427         0   0.06973         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.377       0.621       0.499       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     57/149     23.4G   0.04523   0.02401         0   0.06924        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.389       0.632        0.53       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     58/149     23.4G   0.04523   0.02423         0   0.06946        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.37       0.619         0.5       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     59/149     23.4G   0.04535   0.02424         0    0.0696        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.376       0.638       0.517       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     60/149     23.4G   0.04518   0.02383         0   0.06901        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.395       0.631       0.529       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     61/149     23.4G    0.0454   0.02426         0   0.06965        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.369       0.643       0.514        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     62/149     23.4G   0.04506   0.02418         0   0.06924        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.36       0.632       0.504       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     63/149     23.4G   0.04435   0.02375         0    0.0681        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.423       0.596       0.501       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     64/149     23.4G   0.04419   0.02436         0   0.06855        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.355       0.636       0.491       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     65/149     23.4G   0.04505   0.02382         0   0.06887        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.38       0.629       0.499       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     66/149     23.4G   0.04404   0.02385         0   0.06789         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.383       0.637       0.527       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     67/149     23.4G   0.04476   0.02354         0    0.0683        29      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.385       0.632       0.527       0.155
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     68/149     23.4G   0.04401   0.02369         0    0.0677        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.39       0.616       0.516       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     69/149     23.4G   0.04411   0.02381         0   0.06791        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.414       0.623       0.514       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     70/149     23.4G   0.04436   0.02417         0   0.06853        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.388       0.624       0.508        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     71/149     23.4G   0.04388   0.02405         0   0.06793        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.409       0.625       0.515       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     72/149     23.4G   0.04413   0.02358         0   0.06771        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.392       0.617       0.507        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     73/149     23.4G   0.04324   0.02359         0   0.06683        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.399       0.624       0.511       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     74/149     23.4G   0.04352   0.02326         0   0.06679        26      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.399       0.623       0.513       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     75/149     23.4G   0.04358   0.02412         0    0.0677        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.358       0.616       0.486       0.143
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     76/149     23.4G   0.04333   0.02327         0    0.0666        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.386       0.629       0.507       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     77/149     23.4G   0.04244   0.02346         0   0.06591        24      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.395       0.611       0.495       0.146
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     78/149     23.4G    0.0431   0.02307         0   0.06616        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.374       0.609       0.486       0.146
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     79/149     23.4G   0.04294   0.02341         0   0.06636        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.404       0.612         0.5       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     80/149     23.4G   0.04288   0.02319         0   0.06608        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.402       0.609       0.497       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     81/149     23.4G   0.04289   0.02384         0   0.06673        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03         0.4       0.622       0.525       0.157
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     82/149     23.4G    0.0423   0.02323         0   0.06552        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.401       0.599       0.506       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     83/149     23.4G   0.04244   0.02365         0    0.0661         7      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.396       0.613         0.5       0.146
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     84/149     23.4G   0.04233   0.02335         0   0.06567        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.398       0.603       0.509       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     85/149     23.4G   0.04226     0.023         0   0.06525        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.417       0.608       0.517       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     86/149     23.4G   0.04212   0.02337         0   0.06549        26      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.387        0.62       0.505       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     87/149     23.4G   0.04164   0.02279         0   0.06442        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.38       0.615       0.491       0.146
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     88/149     23.4G   0.04143     0.023         0   0.06443        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.381       0.599       0.495       0.145
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     89/149     23.4G   0.04177   0.02309         0   0.06487        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.389       0.604         0.5       0.145
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     90/149     23.4G   0.04119   0.02314         0   0.06433        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.399       0.608       0.498       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     91/149     23.4G   0.04122   0.02308         0    0.0643        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.403       0.611       0.505        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     92/149     23.4G    0.0409   0.02304         0   0.06394         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03         0.4       0.611       0.499       0.143
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     93/149     23.4G   0.04064    0.0225         0   0.06314         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.403       0.594       0.489       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     94/149     23.4G   0.04053   0.02263         0   0.06316        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.393       0.605        0.49       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     95/149     23.4G   0.04036    0.0227         0   0.06307        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.405       0.598       0.484       0.143
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     96/149     23.4G   0.04081   0.02287         0   0.06368        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.421       0.577       0.481       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     97/149     23.4G   0.04016   0.02221         0   0.06237        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03        0.42       0.585       0.492       0.148
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     98/149     23.4G   0.03993   0.02251         0   0.06244        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.407       0.601       0.496       0.141
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     99/149     23.4G   0.03966   0.02246         0   0.06212        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.414       0.594       0.481       0.138
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    100/149     23.4G    0.0398   0.02215         0   0.06195        27      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.414       0.586       0.484       0.138
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    101/149     23.4G   0.03988   0.02228         0   0.06216        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.409       0.589       0.485        0.14
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    102/149     23.4G   0.03953   0.02219         0   0.06172        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.413       0.593       0.472       0.136
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    103/149     23.4G   0.03937   0.02222         0   0.06159         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.403       0.572       0.457       0.134
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    104/149     23.4G    0.0391    0.0225         0    0.0616        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.408        0.57       0.471       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    105/149     23.4G   0.03876   0.02184         0    0.0606        26      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.416       0.578       0.479       0.138
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    106/149     23.4G   0.03886   0.02188         0   0.06074        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.415       0.575       0.477       0.138
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    107/149     23.4G   0.03833    0.0218         0   0.06013        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.413       0.575       0.474       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    108/149     23.4G   0.03828   0.02171         0   0.05999        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.432       0.581       0.482       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    109/149     23.4G   0.03823   0.02165         0   0.05989        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.425       0.577       0.476       0.137
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    110/149     23.4G   0.03788   0.02179         0   0.05968        24      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.432       0.578        0.49       0.137
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    111/149     23.4G   0.03823   0.02133         0   0.05956        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.436       0.575       0.484       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    112/149     23.4G   0.03754   0.02121         0   0.05876        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.55e+03       0.428       0.573       0.483       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    113/149     23.4G    0.0374    0.0213         0    0.0587        15      1024^C
