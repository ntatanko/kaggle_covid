# %%
import ast
import os
import shutil
import torch
import numpy as np
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import Image, clear_output
from sklearn.model_selection import StratifiedKFold, train_test_split
from tqdm import tqdm
InteractiveShell.ast_node_interactivity = "all"

# %%
# !git clone https://github.com/WongKinYiu/ScaledYOLOv4.git
# !git clone https://github.com/thomasbrandon/mish-cuda
# %cd /app/_data/ScaledYOLOv4/mish-cuda
# !python setup.py build install
clear_output()
# %cd /app/_data/ScaledYOLOv4
! git checkout yolov4-large
# Out:
# /app/_data/ScaledYOLOv4
# M	detect.py
# M	utils/general.py
# Already on 'yolov4-large'
# Your branch is up to date with 'origin/yolov4-large'.

# %% [markdown]
# ## preparing data

# %%
df = pd.read_csv("/app/_data/bboxes.csv")
df['path'] = '/app/_data/yolo5_dataset/'+df['img']+'.jpg'
base_config = {
    "IMG_SIZE": 1024,
    "BATCH_SIZE": 10,
    "SEED": 42,
}

# %%
df
# Out:
#              study           img     label  bbox  x_center  y_center  \
# 0     5776db0cec75  000a312787f2   typical     1  0.306066  0.441824
# 1     5776db0cec75  000a312787f2   typical     1  0.656307  0.422013
# 2     ff0879eb20ed  000c3a3f293f  negative     0       NaN       NaN
# 3     9d514ce429a7  0012ff7358bc   typical     1  0.363652  0.274319
# 4     9d514ce429a7  0012ff7358bc   typical     1  0.687567  0.394942
# ...            ...           ...       ...   ...       ...       ...
# 9584  7eed9af03814  ffd9b6cf2961   typical     1  0.296171  0.480181
# 9585  a0cb0b96fb3d  ffdc682f7680   typical     1  0.817057  0.468622
# 9586  a0cb0b96fb3d  ffdc682f7680   typical     1  0.314128  0.565537
# 9587  7d82d53204b8  ffe942c8655f   typical     1  0.313157  0.355756
# 9588  7d82d53204b8  ffe942c8655f   typical     1  0.698962  0.366852
#
#          width    height  class                                       path
# 0     0.241226  0.549685      0  /app/_data/yolo5_dataset/000a312787f2.jpg
# 1     0.257204  0.505031      0  /app/_data/yolo5_dataset/000a312787f2.jpg
# 2          NaN       NaN      0  /app/_data/yolo5_dataset/000c3a3f293f.jpg
# 3     0.283965  0.392996      0  /app/_data/yolo5_dataset/0012ff7358bc.jpg
# 4     0.201907  0.473411      0  /app/_data/yolo5_dataset/0012ff7358bc.jpg
# ...        ...       ...    ...                                        ...
# 9584  0.128571  0.355606      0  /app/_data/yolo5_dataset/ffd9b6cf2961.jpg
# 9585  0.351563  0.746727      0  /app/_data/yolo5_dataset/ffdc682f7680.jpg
# 9586  0.155599  0.222429      0  /app/_data/yolo5_dataset/ffdc682f7680.jpg
# 9587  0.325139  0.550925      0  /app/_data/yolo5_dataset/ffe942c8655f.jpg
# 9588  0.308485  0.480492      0  /app/_data/yolo5_dataset/ffe942c8655f.jpg
#
# [9589 rows x 10 columns]

# %%
groupped_data =pd.pivot_table(df,index='img', values=['label', 'bbox', 'path'],aggfunc='first')
groupped_data['img'] = groupped_data.index
groupped_data = groupped_data.reset_index(drop=True)
groupped_data.head()
groupped_data['bbox'].value_counts()
# Out:
#    bbox     label                                       path           img
# 0     1   typical  /app/_data/yolo5_dataset/000a312787f2.jpg  000a312787f2
# 1     0  negative  /app/_data/yolo5_dataset/000c3a3f293f.jpg  000c3a3f293f
# 2     1   typical  /app/_data/yolo5_dataset/0012ff7358bc.jpg  0012ff7358bc
# 3     1  atypical  /app/_data/yolo5_dataset/001398f4ff4f.jpg  001398f4ff4f
# 4     1   typical  /app/_data/yolo5_dataset/001bd15d1891.jpg  001bd15d1891
# 1    4294
# 0    1736
# Name: bbox, dtype: int64

# %%
skf = StratifiedKFold(n_splits=5, random_state=base_config["SEED"], shuffle=True)
train_ids = []
val_ids = []
for train_index, valid_index in skf.split(groupped_data, groupped_data['label']):
    train_ids.append(train_index)
    val_ids.append(valid_index)

# %%
if not os.path.exists('/app/_data/yolo5_dataset/yolo4/'):
    os.mkdir('/app/_data/yolo5_dataset/yolo4/')
for i in range(5):
    train_img_path = groupped_data.loc[train_ids[i]]['path'].tolist()
    val_img_path = groupped_data.loc[val_ids[i]]['path'].tolist()
    np.savetxt("/app/_data/yolo5_dataset/yolo4/train_"+str(i)+".txt", train_img_path, fmt='%s')
    np.savetxt("/app/_data/yolo5_dataset/yolo4/val_"+str(i)+".txt", val_img_path, fmt='%s')

# %%
for img_name in tqdm(df['img'].unique().tolist()):
    new_df = df[df['img']==img_name].reset_index(drop=True)
    if new_df.loc[0,'bbox']==1:
        boxes = new_df[['label', 'x_center','y_center','width','height']].values
        list_boxes = []
        for box in boxes:
            list_boxes.append(
                [
                    str(labels[box[0]]),
                    str(box[1]),
                    str(box[2]),
                    str(box[3]),
                    str(box[4]),
                ]
            )
        np.savetxt("/app/_data/yolo5_dataset/yolo4/"+img_name+".txt", list_boxes, fmt='%s')
clear_output()

# %% [markdown]
# ## Writing data.yaml and custom parameters yolov4-p7

# %%
# customize iPython writefile so we can write variables

from IPython.core.magic import register_line_cell_magic


@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, "w") as f:
        f.write(cell.format(**globals()))

# %%
if not os.path.exists("/app/_data/ScaledYOLOv4/data/DataFile"):
    os.mkdir("/app/_data/ScaledYOLOv4/data/DataFile")

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/data.yaml
# # train and val datasets (image directory or *.txt file with image paths)
# train: /app/_data/yolo5_dataset/yolo4/train_0.txt
# val: /app/_data/yolo5_dataset/yolo4/val_0.txt
# # number of classes
# nc: 3
# # class names
# names: ["typical", "indeterminate","atypical"]

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml
# # parameters yolov4-p7
# nc: 3  # number of classes
# depth_multiple: 1.0  # expand model depth
# width_multiple: 1.25  # expand layer channels
#
# # anchors
# anchors:
#   - [13,17,  22,25,  27,66,  55,41]  # P3/8
#   - [57,88,  112,69,  69,177,  136,138]  # P4/16
#   - [136,138,  287,114,  134,275,  268,248]  # P5/32
#   - [268,248,  232,504,  445,416,  640,640]  # P6/64
#   - [812,393,  477,808,  1070,908,  1408,1408]  # P7/128
#
# # csp-p7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, BottleneckCSP, [64]],
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 5-P3/8
#    [-1, 15, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 7-P4/16
#    [-1, 15, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]], # 9-P5/32
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 11-P6/64
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 13-P7/128
#    [-1, 7, BottleneckCSP, [1024]],  # 14
#   ]
#
# # yolov4-p7 head
# # na = len(anchors[0])
# head:
#   [[-1, 1, SPPCSP, [512]], # 15
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-6, 1, Conv, [512, 1, 1]], # route backbone P6
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 20
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-13, 1, Conv, [512, 1, 1]], # route backbone P5
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 25
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-20, 1, Conv, [256, 1, 1]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [256]], # 30
#    [-1, 1, Conv, [128, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-27, 1, Conv, [128, 1, 1]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [128]], # 35
#    [-1, 1, Conv, [256, 3, 1]],
#    [-2, 1, Conv, [256, 3, 2]],
#    [[-1, 30], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [256]], # 39
#    [-1, 1, Conv, [512, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 25], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 43
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 20], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 47
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 15], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 51
#    [-1, 1, Conv, [1024, 3, 1]],
#
#    [[36,40,44,48,52], 1, Detect, [nc, anchors]],   # Detect(P3, P4, P5, P6, P7)
#   ]

# %% [markdown]
# ## train

# %%
# !python train.py --img 1024 \
                 --batch 6 \
                 --epochs 150 \
                 --data /app/_data/ScaledYOLOv4/data/DataFile/data.yaml \
                 --cfg /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml \
                 --weights /app/_data/ScaledYOLOv4/runs/exp8_yolov4lp7_3cl_42/weights/best_yolov4lp7_3cl_42_strip.pt \
                 --name yolov4lp7_3cl_42 \
                 --cache
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090', total_memory=24268MB)
#
# Namespace(adam=False, batch_size=6, bucket='', cache_images=True, cfg='/app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml', data='/app/_data/ScaledYOLOv4/data/DataFile/data.yaml', device='', epochs=150, evolve=False, global_rank=-1, hyp='data/hyp.finetune.yaml', img_size=[1024, 1024], local_rank=-1, logdir='runs/', multi_scale=False, name='yolov4lp7_3cl_42', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=6, weights='/app/_data/ScaledYOLOv4/runs/exp8_yolov4lp7_3cl_42/weights/best_yolov4lp7_3cl_42_strip.pt', world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# Hyperparameters {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.5, 'scale': 0.8, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mixup': 0.2}
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     23200  models.common.Conv                      [32, 80, 3, 2]
#   2                -1  1     30960  models.common.BottleneckCSP             [80, 80, 1]
#   3                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   4                -1  1    251360  models.common.BottleneckCSP             [160, 160, 3]
#   5                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   6                -1  1   4081600  models.common.BottleneckCSP             [320, 320, 15]
#   7                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   8                -1  1  16304000  models.common.BottleneckCSP             [640, 640, 15]
#   9                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#  10                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  11                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  12                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  13                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  14                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  15                -1  1  11888640  models.common.SPPCSP                    [1280, 640, 1]
#  16                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18                -6  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  19          [-1, -2]  1         0  models.common.Concat                    [1]
#  20                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  21                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  22                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  23               -13  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  24          [-1, -2]  1         0  models.common.Concat                    [1]
#  25                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  26                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  27                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  28               -20  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  29          [-1, -2]  1         0  models.common.Concat                    [1]
#  30                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  31                -1  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  32                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  33               -27  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  34          [-1, -2]  1         0  models.common.Concat                    [1]
#  35                -1  1    899200  models.common.BottleneckCSP2            [320, 160, 3]
#  36                -1  1    461440  models.common.Conv                      [160, 320, 3, 1]
#  37                -2  1    461440  models.common.Conv                      [160, 320, 3, 2]
#  38          [-1, 30]  1         0  models.common.Concat                    [1]
#  39                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  40                -1  1   1844480  models.common.Conv                      [320, 640, 3, 1]
#  41                -2  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#  42          [-1, 25]  1         0  models.common.Concat                    [1]
#  43                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  44                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  45                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  46          [-1, 20]  1         0  models.common.Concat                    [1]
#  47                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  48                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  49                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  50          [-1, 15]  1         0  models.common.Concat                    [1]
#  51                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  52                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  53[36, 40, 44, 48, 52]  1    153760  models.yolo.Detect                      [3, [[13, 17, 22, 25, 27, 66, 55, 41], [57, 88, 112, 69, 69, 177, 136, 138], [136, 138, 287, 114, 134, 275, 268, 248], [268, 248, 232, 504, 445, 416, 640, 640], [812, 393, 477, 808, 1070, 908, 1408, 1408]], [320, 640, 1280, 1280, 1280]]
# Model Summary: 722 layers, 2.8609e+08 parameters, 2.8609e+08 gradients
#
# Transferred 1427/1429 items from /app/_data/ScaledYOLOv4/runs/exp8_yolov4lp7_3cl_42/weights/best_yolov4lp7_3cl_42_strip.pt
# Optimizer groups: 240 .bias, 247 conv.weight, 235 other
# Scanning images: 100%|████████████████████| 4824/4824 [00:00<00:00, 7733.29it/s]
# Scanning labels /app/_data/yolo5_dataset.cache (3435 found, 0 missing, 1389 empt
# Caching images (13.0GB): 100%|██████████████| 4824/4824 [06:55<00:00, 11.60it/s]
# Scanning images: 100%|████████████████████| 1206/1206 [00:00<00:00, 7792.95it/s]
# Scanning labels /app/_data/yolo5_dataset.cache (859 found, 0 missing, 347 empty,
# Caching images (3.3GB): 100%|███████████████| 1206/1206 [03:00<00:00,  6.69it/s]
#
# Analyzing anchors... anchors/target = 11.63, Best Possible Recall (BPR) = 1.0000
# Image sizes 1024 train, 1024 test
# Using 6 dataloader workers
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      0/149     23.1G   0.04639   0.02511 4.565e-05   0.07154         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.331       0.662        0.53       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      1/149     23.1G   0.04827   0.02529 6.272e-05   0.07363         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.311        0.66        0.51       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      2/149     23.1G   0.04939   0.02563 0.0001217   0.07515        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.343       0.618       0.479       0.141
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      3/149     23.1G   0.05061    0.0264 0.0001627   0.07718        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.325        0.62       0.485       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      4/149     23.1G   0.05126   0.02584 0.0001653   0.07726        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.282       0.668         0.5       0.131
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      5/149     23.1G   0.05033   0.02614 0.0001416   0.07661        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.246       0.674       0.487       0.141
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      6/149     23.1G   0.05127   0.02589  0.000148    0.0773        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.275        0.67       0.485       0.142
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      7/149     23.1G    0.0508   0.02597  0.000134    0.0769        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.271       0.675       0.492        0.14
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      8/149     23.1G   0.05056   0.02574  0.000138   0.07644         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.313       0.641       0.502       0.145
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      9/149     23.1G    0.0504   0.02605 0.0001403   0.07659        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.346       0.593       0.488       0.134
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     10/149     23.2G   0.05067   0.02541 0.0001375   0.07621        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.357       0.637       0.509       0.148
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     11/149     23.2G   0.04997   0.02539 0.0001402    0.0755        27      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.333       0.648       0.501       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     12/149     23.2G   0.05033   0.02592 0.0001453    0.0764        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.337       0.641       0.495       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     13/149     23.2G   0.05056   0.02568 0.0001424   0.07639        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.284       0.638       0.483       0.139
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     14/149     23.2G   0.05017   0.02611 0.0001453   0.07643        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.381       0.612       0.502       0.147
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     15/149     23.2G   0.05031   0.02599 0.0001241   0.07643        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.381       0.614       0.512       0.151
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     16/149     23.2G   0.05032   0.02603 0.0001253   0.07648        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.304        0.64       0.494       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     17/149     23.2G   0.05015   0.02566  0.000143   0.07595        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.343       0.643       0.507       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     18/149     23.2G   0.05013   0.02526 0.0001456   0.07553        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.295       0.653       0.484       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     19/149     23.2G   0.05023   0.02579 0.0001264   0.07615        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.346       0.646       0.516       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     20/149     23.2G   0.05033   0.02584 0.0001305    0.0763        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.277       0.687       0.501        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     21/149     23.2G   0.05007   0.02586 0.0001165   0.07605        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.337       0.681       0.533       0.161
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     22/149     23.2G   0.04974   0.02563 0.0001231    0.0755        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.364       0.627       0.515       0.156
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     23/149     23.2G   0.04977   0.02582 0.0001223   0.07571        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.339       0.637       0.508       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     24/149     23.2G   0.04962   0.02571 0.0001218   0.07546        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.334       0.657       0.516        0.16
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     25/149     23.2G   0.04931   0.02529 0.0001116   0.07472        24      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.343       0.644       0.517       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     26/149     23.2G   0.04971   0.02553 0.0001358   0.07538        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.355       0.655       0.523       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     27/149     23.2G   0.04957   0.02588 0.0001182   0.07556        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.307       0.679       0.522       0.155
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     28/149     23.2G   0.04945   0.02517 0.0001206   0.07474        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.337       0.652       0.515       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     29/149     23.2G   0.04983   0.02564 0.0001246    0.0756        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.342       0.659       0.524       0.149
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     30/149     23.2G   0.04986   0.02561 0.0001074   0.07558        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.409        0.63       0.538       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     31/149     23.2G    0.0495   0.02546 0.0001147   0.07507         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.367       0.618       0.509       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     32/149     23.2G   0.04952   0.02546 0.0001204    0.0751        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.334       0.652        0.52       0.157
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     33/149     23.2G   0.04969   0.02549 0.0001138    0.0753        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.334       0.656       0.518       0.159
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     34/149     23.2G   0.04919   0.02507 0.0001082   0.07437        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.335       0.655       0.516        0.16
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     35/149     23.2G    0.0497   0.02555 0.0001065   0.07536        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.348       0.629       0.495       0.157
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     36/149     23.2G   0.04968   0.02516 0.0001196   0.07496        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.347       0.645       0.517       0.161
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     37/149     23.2G   0.04929    0.0257 0.0001331   0.07512        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.297       0.654       0.496       0.152
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     38/149     23.2G   0.04934   0.02511 0.0001187   0.07456        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.315       0.668       0.521       0.162
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     39/149     23.2G   0.04905   0.02548 0.0001046   0.07463        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.327       0.648       0.516       0.159
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     40/149     23.2G   0.04937   0.02564 0.0001111   0.07512        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.35       0.632       0.515       0.153
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     41/149     23.2G   0.04932   0.02523 0.0001509    0.0747        30      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.364       0.634       0.516        0.16
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     42/149     23.2G   0.04935   0.02595 0.0001113   0.07541        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.378       0.622       0.505       0.144
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     43/149     23.2G   0.04911   0.02588 0.0001134   0.07511        28      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.332       0.653       0.509        0.15
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     44/149     23.2G   0.04926   0.02574 0.0001033    0.0751        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.359       0.627       0.514       0.154
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     45/149     23.2G   0.04881   0.02503  9.78e-05   0.07394         6      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.355       0.632       0.498       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     46/149     23.2G   0.04907   0.02534 0.0001013   0.07451        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.349       0.637       0.518       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     47/149     23.2G   0.04893   0.02516 9.905e-05   0.07419        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.335       0.662       0.522       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     48/149     23.2G   0.04882   0.02553 9.605e-05   0.07445        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.336       0.648       0.512       0.162
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     49/149     23.2G   0.04896    0.0251 0.0001052   0.07417        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.347       0.655       0.527       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     50/149     23.2G   0.04866   0.02508 0.0001069   0.07384         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.363        0.65       0.528       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     51/149     23.2G   0.04889   0.02512 0.0001033   0.07411        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.328       0.678        0.53       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     52/149     23.2G    0.0485   0.02535 9.799e-05   0.07394        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.356       0.646       0.523       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     53/149     23.2G    0.0485   0.02509 9.992e-05   0.07369        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.35       0.655       0.541       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     54/149     23.2G   0.04853   0.02561 0.0001116   0.07425        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.355       0.668       0.532       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     55/149     23.2G   0.04879   0.02546  0.000106   0.07435        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.367       0.649       0.525       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     56/149     23.2G   0.04823   0.02569 9.452e-05   0.07402        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.339       0.656       0.523        0.16
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     57/149     23.2G   0.04838   0.02455 0.0001052   0.07303        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.37       0.646       0.527       0.159
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     58/149     23.2G   0.04825   0.02566 9.526e-05     0.074        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.351       0.652       0.515       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     59/149     23.2G   0.04856   0.02508 9.445e-05   0.07374        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.359       0.664       0.538       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     60/149     23.2G   0.04842   0.02532 0.0001078   0.07385        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.363       0.657       0.535       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     61/149     23.2G   0.04848   0.02523 9.749e-05   0.07381         7      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.363       0.637       0.528       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     62/149     23.2G   0.04827   0.02527 9.275e-05   0.07363        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.364       0.659       0.542       0.172
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     63/149     23.2G   0.04804   0.02521 8.504e-05   0.07333        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.345        0.66       0.534       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     64/149     23.2G   0.04806   0.02487 9.904e-05   0.07303        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.372       0.647       0.537       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     65/149     23.2G   0.04783   0.02504 9.149e-05   0.07297        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.365       0.653       0.536       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     66/149     23.2G   0.04746   0.02453 8.558e-05   0.07207        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.353       0.674       0.539       0.174
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     67/149     23.2G   0.04765   0.02483  9.13e-05   0.07257        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.334       0.666       0.534       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     68/149     23.2G   0.04801   0.02532 8.357e-05   0.07341        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.36        0.66       0.543       0.162
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     69/149     23.2G   0.04754   0.02519 9.261e-05   0.07282        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.338       0.664       0.537       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     70/149     23.2G   0.04808   0.02496 7.715e-05   0.07312         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.359       0.673       0.548       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     71/149     23.2G    0.0475   0.02476 8.241e-05   0.07234        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.354       0.661       0.542       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     72/149     23.2G   0.04745   0.02508 8.014e-05   0.07261         7      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.365       0.648        0.54       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     73/149     23.2G   0.04765   0.02502 7.875e-05   0.07275         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.34       0.666        0.54       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     74/149     23.2G   0.04761   0.02461 7.956e-05    0.0723        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.363       0.648       0.538       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     75/149     23.2G    0.0474   0.02491 7.497e-05   0.07239        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.384        0.65       0.538       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     76/149     23.2G   0.04754   0.02485 8.308e-05   0.07247        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.36       0.654        0.53       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     77/149     23.2G   0.04773   0.02468 7.676e-05   0.07249        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.354       0.658       0.533       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     78/149     23.2G   0.04724   0.02468 8.849e-05   0.07202        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.366       0.663       0.539       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     79/149     23.2G   0.04735   0.02488 7.776e-05    0.0723        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.342       0.643       0.535       0.162
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     80/149     23.2G   0.04735   0.02455 7.988e-05   0.07197        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.366       0.646       0.538       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     81/149     23.2G   0.04727   0.02443 7.808e-05   0.07178        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.361       0.646       0.533       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     82/149     23.2G   0.04727   0.02492 7.136e-05   0.07226        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.368       0.646       0.527       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     83/149     23.2G   0.04728   0.02506 7.361e-05   0.07242        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.358       0.653       0.538       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     84/149     23.2G    0.0472   0.02513 7.444e-05    0.0724         7      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.361       0.655       0.535       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     85/149     23.2G    0.0468   0.02489 7.182e-05   0.07176        28      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.37       0.656       0.537       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     86/149     23.2G   0.04719   0.02452 6.997e-05   0.07179        26      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.392       0.654       0.553       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     87/149     23.2G   0.04665   0.02483 6.982e-05   0.07155        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.365       0.666       0.546       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     88/149     23.2G   0.04667   0.02479 7.043e-05   0.07153        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.384       0.639       0.526       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     89/149     23.2G   0.04666   0.02463 7.316e-05   0.07136         7      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.371       0.655       0.543       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     90/149     23.2G   0.04649   0.02478 7.022e-05   0.07134        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.366       0.658       0.539       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     91/149     23.2G   0.04665   0.02463 6.723e-05   0.07134        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.386       0.644        0.54       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     92/149     23.2G   0.04633   0.02471  7.58e-05   0.07111         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.374       0.644       0.536       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     93/149     23.2G   0.04658   0.02439 7.887e-05   0.07105         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.377       0.641       0.527       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     94/149     23.2G   0.04677   0.02476 6.925e-05    0.0716        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.358       0.658       0.538       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     95/149     23.2G   0.04648   0.02511 6.632e-05   0.07166        20      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.371       0.649       0.539       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     96/149     23.2G   0.04573   0.02454 6.579e-05   0.07034        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.373       0.639       0.528       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     97/149     23.2G   0.04638   0.02454 6.772e-05   0.07099        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.369       0.648       0.533       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     98/149     23.2G   0.04607   0.02486 5.991e-05   0.07099        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.369       0.645       0.533       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     99/149     23.2G   0.04634   0.02485 6.215e-05   0.07125         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.37       0.655       0.539       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    100/149     23.2G   0.04626   0.02466 6.558e-05   0.07099        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.364       0.655        0.53       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    101/149     23.2G   0.04604   0.02446  5.95e-05   0.07056        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.372        0.65       0.533       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    102/149     23.2G   0.04568   0.02462  6.17e-05   0.07035         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.379       0.651       0.537       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    103/149     23.2G    0.0457   0.02494   5.9e-05    0.0707        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.383       0.641       0.533       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    104/149     23.2G   0.04563    0.0243 6.027e-05   0.06999        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.372       0.639       0.525       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    105/149     23.2G   0.04581   0.02441 6.179e-05   0.07029        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.372        0.64       0.536       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    106/149     23.2G   0.04504    0.0244 5.384e-05   0.06949        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.366       0.633       0.529       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    107/149     23.2G   0.04556   0.02427 6.065e-05   0.06988        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.384       0.639       0.533       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    108/149     23.2G   0.04531   0.02388  5.29e-05   0.06925         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.381       0.645       0.533       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    109/149     23.2G   0.04531   0.02432  5.76e-05   0.06969        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.376       0.645       0.531       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    110/149     23.2G   0.04516   0.02423 7.451e-05   0.06946        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.376       0.646       0.539       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    111/149     23.2G    0.0452   0.02424 5.529e-05   0.06949        19      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.383       0.641       0.537       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    112/149     23.2G   0.04502   0.02449 5.282e-05   0.06956         4      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.387       0.635       0.528       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    113/149     23.2G   0.04551   0.02443 5.434e-05      0.07        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.388       0.644       0.538       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    114/149     23.2G   0.04527   0.02435 5.523e-05   0.06967        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.37        0.65       0.533       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    115/149     23.2G   0.04499   0.02452 5.418e-05   0.06956        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.376       0.639       0.529       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    116/149     23.2G   0.04474   0.02425 5.241e-05   0.06904        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.382       0.648       0.537        0.17
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    117/149     23.2G   0.04484   0.02408 5.958e-05   0.06898        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.38       0.653       0.533       0.171
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    118/149     23.2G   0.04484   0.02398 4.893e-05   0.06887        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.379       0.649       0.536       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    119/149     23.2G   0.04467   0.02387  4.67e-05   0.06858        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.383       0.639       0.534       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    120/149     23.2G   0.04444   0.02406 5.495e-05   0.06855         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.38       0.634        0.53       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    121/149     23.2G   0.04442   0.02384 5.015e-05   0.06831        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.384       0.641       0.531       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    122/149     23.2G   0.04428   0.02387 5.092e-05   0.06819         8      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.385       0.632        0.53       0.167
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    123/149     23.2G   0.04409   0.02423 4.617e-05   0.06837        14      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.39       0.634       0.533       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    124/149     23.2G   0.04459   0.02393 5.728e-05   0.06858        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.395       0.628       0.529        0.17
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    125/149     23.2G   0.04408   0.02371 5.603e-05   0.06784        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.396       0.627       0.531       0.169
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    126/149     23.2G   0.04416    0.0243 5.497e-05   0.06852        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.398       0.628        0.53       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    127/149     23.2G   0.04404   0.02391 4.795e-05   0.06799         6      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.397       0.632       0.531       0.168
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    128/149     23.2G   0.04407   0.02394 5.755e-05   0.06806        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.397       0.632       0.527       0.166
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    129/149     23.2G   0.04375   0.02393 4.685e-05   0.06772        16      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.395       0.639       0.528       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    130/149     23.2G   0.04347    0.0241 4.333e-05   0.06761        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.389       0.629       0.524       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    131/149     23.2G   0.04376   0.02407 4.398e-05   0.06788        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.389       0.624       0.522       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    132/149     23.2G   0.04363   0.02397 4.323e-05   0.06765        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.393       0.628       0.526       0.165
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    133/149     23.2G   0.04374    0.0241 4.231e-05   0.06789         9      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.399       0.631       0.526       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    134/149     23.2G   0.04361   0.02368 4.479e-05   0.06734        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03         0.4       0.633       0.519       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    135/149     23.2G   0.04328   0.02359 4.405e-05   0.06692        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.399       0.632       0.521       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    136/149     23.2G    0.0434   0.02402 4.265e-05   0.06746        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.397       0.632       0.518       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    137/149     23.2G   0.04297    0.0234  4.21e-05   0.06641        10      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.391       0.629       0.521       0.164
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    138/149     23.2G   0.04303    0.0239  5.64e-05   0.06699        17      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.394       0.636       0.519       0.162
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    139/149     23.2G   0.04307   0.02407 4.015e-05   0.06718        11      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.391       0.627       0.509       0.161
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    140/149     23.2G   0.04308   0.02364  4.36e-05   0.06677        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.393        0.63       0.519       0.163
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    141/149     23.2G   0.04347   0.02384 4.111e-05   0.06735        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.394       0.622       0.516       0.162
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    142/149     23.2G   0.04329    0.0241 4.124e-05   0.06744        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.39        0.62       0.513        0.16
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    143/149     23.2G   0.04289   0.02361 3.977e-05   0.06654        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.391       0.623       0.513       0.159
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    144/149     23.2G   0.04267   0.02372 4.075e-05   0.06643        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.394        0.62       0.511       0.158
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    145/149     23.2G   0.04313   0.02314 5.365e-05   0.06633        12      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.387       0.609         0.5       0.157
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    146/149     23.2G   0.04236   0.02345 4.101e-05   0.06586        18      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03        0.39       0.614       0.504       0.155
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    147/149     23.2G   0.04244   0.02345 5.545e-05   0.06594        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.391       0.621       0.504       0.156
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    148/149     23.2G   0.04266    0.0236 4.145e-05    0.0663        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.394       0.626        0.51       0.157
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#    149/149     23.2G   0.04263   0.02359 3.898e-05   0.06626        13      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    1.56e+03       0.394        0.62       0.512       0.158
# Optimizer stripped from runs/exp9_yolov4lp7_3cl_42/weights/last_yolov4lp7_3cl_42.pt, saved as runs/exp9_yolov4lp7_3cl_42/weights/last_yolov4lp7_3cl_42_strip.pt, 573.4MB
# Optimizer stripped from runs/exp9_yolov4lp7_3cl_42/weights/best_yolov4lp7_3cl_42.pt, saved as runs/exp9_yolov4lp7_3cl_42/weights/best_yolov4lp7_3cl_42_strip.pt, 573.4MB
# 150 epochs completed in 32.499 hours.
