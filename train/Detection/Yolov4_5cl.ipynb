# %%
import ast
import os
import shutil

import cv2
import numpy as np
import pandas as pd
import torch
from IPython.core.interactiveshell import InteractiveShell
from IPython.display import Image, clear_output
from sklearn.model_selection import StratifiedKFold, train_test_split
from tqdm import tqdm
from PIL import Image
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.pyplot as plt
import pydicom as dicom

# %%
# !git clone https://github.com/WongKinYiu/ScaledYOLOv4.git
# !git clone https://github.com/thomasbrandon/mish-cuda
# %cd /app/_data/ScaledYOLOv4/mish-cuda
# !python setup.py build install
clear_output()
# %cd /app/_data/ScaledYOLOv4
! git checkout yolov4-large
# Out:
# /app/_data/ScaledYOLOv4
# M	detect.py
# M	utils/datasets.py
# M	utils/general.py
# Already on 'yolov4-large'
# Your branch is up to date with 'origin/yolov4-large'.

# %%
labels = {"negative": 0, "typical": 1, "indeterminate": 2, "atypical": 3, "opacity": 4}

# %% [markdown]
# # preparing images

# %%
dicom_df = pd.read_csv("/app/_data/train.csv")

# %%
dicom_df['image'] = dicom_df['image'].str[:-4]

# %%
list_wrong = dicom_df[(dicom_df["class"] != "negative") & (dicom_df["label"] == "none 1 0 0 1 1")][
    "id_image"
].tolist()
dicom_df = dicom_df.query("id_image not in @list_wrong").reset_index(drop=True)

# %%
resized_yolo_path = "/app/_data/yolo4_dataset/resized_yolo_1024_npy/images/"
os.makedirs(resized_yolo_path)

# %%
# for ix in tqdm(dicom_df.index.tolist()):
#     img_path = dicom_df.loc[ix, 'path']
#     data_file = dicom.dcmread(img_path)
#     image_name = dicom_df.loc[ix, 'image']
#     img = data_file.pixel_array
#     if dicom_df.loc[ix, 'PhotometricInterpretation'] == "MONOCHROME1":
#         img = img.max() - img
#     img = (img - img.min()) / (img.max() - img.min())
#     img = (np.array(img) * 255).astype("uint8")
#     img = np.stack([img, img, img], axis=-1)
#     h0, w0 = img.shape[:2]
#     r = 1024 / max(h0, w0)
#     img_yolo = cv2.resize(img, (int(w0 * r), int(h0 * r)), interpolation=cv2.INTER_LINEAR)
#     img_yolo = Image.fromarray(img_yolo)
#     img_yolo.save(resized_yolo_path + image_name+'.png', format = 'PNG')

# %% [markdown]
# ## preparing data

# %%
df = pd.read_csv("/app/_data/bboxes.csv")
df["path"] = resized_yolo_path + df["img"] + ".png"
base_config = {
    "IMG_SIZE": 1024,
    "BATCH_SIZE": 10,
    "SEED": 42,
}

# %%
df = df.query("img not in @list_wrong").reset_index(drop=True)
df
# Out:
#              study           img     label  bbox  x_center  y_center  \
# 0     5776db0cec75  000a312787f2   typical     1  0.306066  0.441824
# 1     5776db0cec75  000a312787f2   typical     1  0.656307  0.422013
# 2     ff0879eb20ed  000c3a3f293f  negative     0       NaN       NaN
# 3     9d514ce429a7  0012ff7358bc   typical     1  0.363652  0.274319
# 4     9d514ce429a7  0012ff7358bc   typical     1  0.687567  0.394942
# ...            ...           ...       ...   ...       ...       ...
# 9584  7eed9af03814  ffd9b6cf2961   typical     1  0.296171  0.480181
# 9585  a0cb0b96fb3d  ffdc682f7680   typical     1  0.817057  0.468622
# 9586  a0cb0b96fb3d  ffdc682f7680   typical     1  0.314128  0.565537
# 9587  7d82d53204b8  ffe942c8655f   typical     1  0.313157  0.355756
# 9588  7d82d53204b8  ffe942c8655f   typical     1  0.698962  0.366852
#
#          width    height  class  \
# 0     0.241226  0.549685      0
# 1     0.257204  0.505031      0
# 2          NaN       NaN      0
# 3     0.283965  0.392996      0
# 4     0.201907  0.473411      0
# ...        ...       ...    ...
# 9584  0.128571  0.355606      0
# 9585  0.351563  0.746727      0
# 9586  0.155599  0.222429      0
# 9587  0.325139  0.550925      0
# 9588  0.308485  0.480492      0
#
#                                                    path
# 0     /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 1     /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 2     /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 3     /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 4     /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# ...                                                 ...
# 9584  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 9585  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 9586  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 9587  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 9588  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
#
# [9589 rows x 10 columns]

# %%
groupped_data = pd.pivot_table(
    df, index="img", values=["label", "bbox", "path"], aggfunc="first"
)
groupped_data["img"] = groupped_data.index
groupped_data = groupped_data.reset_index(drop=True)
groupped_data.head()
groupped_data["bbox"].value_counts()
# Out:
#    bbox     label                                               path  \
# 0     1   typical  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 1     0  negative  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 2     1   typical  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 3     1  atypical  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
# 4     1   typical  /app/_data/yolo4_dataset/resized_yolo_1024_npy...
#
#             img
# 0  000a312787f2
# 1  000c3a3f293f
# 2  0012ff7358bc
# 3  001398f4ff4f
# 4  001bd15d1891
# 1    4294
# 0    1736
# Name: bbox, dtype: int64

# %%
skf = StratifiedKFold(n_splits=5, random_state=base_config["SEED"], shuffle=True)
train_ids = []
val_ids = []
for train_index, valid_index in skf.split(groupped_data, groupped_data["label"]):
    train_ids.append(train_index)
    val_ids.append(valid_index)

# %%
if not os.path.exists("/app/_data/yolo4_dataset/"):
    os.mkdir("/app/_data/yolo4_dataset/")
for i in range(5):
    train_img_path = groupped_data.loc[train_ids[i]]["path"].tolist()
    val_img_path = groupped_data.loc[val_ids[i]]["path"].tolist()
    np.savetxt(
        "/app/_data/yolo4_dataset/train_" + str(i) + ".txt", train_img_path, fmt="%s"
    )
    np.savetxt(
        "/app/_data/yolo4_dataset/val_" + str(i) + ".txt", val_img_path, fmt="%s"
    )

# %%
for img_name in tqdm(df["img"].unique().tolist()):
    new_df = df[df["img"] == img_name].reset_index(drop=True)
    list_boxes = []
    if new_df.loc[0, "bbox"] == 1:
        boxes = new_df[["x_center", "y_center", "width", "height"]].values
        for box in boxes:
            list_boxes.append(
                [
                    str(labels["opacity"]),
                    str(box[0]),
                    str(box[1]),
                    str(box[2]),
                    str(box[3]),
                ]
            )
    list_boxes.append([str(labels[new_df.loc[0, "label"]]), "0.5", "0.5", "1", "1"])
    np.savetxt(
        "/app/_data/yolo4_dataset/resized_yolo_1024_npy/labels/" + img_name + ".txt",
        list_boxes,
        fmt="%s",
    )
clear_output()

# %% [markdown]
# ## Writing data.yaml and custom parameters yolov4-p7

# %%
# customize iPython writefile so we can write variables

from IPython.core.magic import register_line_cell_magic


@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, "w") as f:
        f.write(cell.format(**globals()))

# %%
if not os.path.exists("/app/_data/ScaledYOLOv4/data/DataFile"):
    os.mkdir("/app/_data/ScaledYOLOv4/data/DataFile")

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/data.yaml
# # train and val datasets (image directory or *.txt file with image paths)
# train: /app/_data/yolo4_dataset/train_0.txt
# val: /app/_data/yolo4_dataset/val_0.txt
# # number of classes
# nc: 5
# # class names
# names: ["negative", "typical", "indeterminate", "atypical", "opacity"]

# %%
# %%writetemplate /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml
# # parameters yolov4-p7
# nc: 5  # number of classes
# depth_multiple: 1.0  # expand model depth
# width_multiple: 1.25  # expand layer channels
#
# # anchors
# anchors:
#   - [13,17,  22,25,  27,66,  55,41]  # P3/8
#   - [57,88,  112,69,  69,177,  136,138]  # P4/16
#   - [136,138,  287,114,  134,275,  268,248]  # P5/32
#   - [268,248,  232,504,  445,416,  640,640]  # P6/64
#   - [812,393,  477,808,  1070,908,  1408,1408]  # P7/128
#
# # csp-p7 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [32, 3, 1]],  # 0
#    [-1, 1, Conv, [64, 3, 2]],  # 1-P1/2
#    [-1, 1, BottleneckCSP, [64]],
#    [-1, 1, Conv, [128, 3, 2]],  # 3-P2/4
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 5-P3/8
#    [-1, 15, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 7-P4/16
#    [-1, 15, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]], # 9-P5/32
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 11-P6/64
#    [-1, 7, BottleneckCSP, [1024]],
#    [-1, 1, Conv, [1024, 3, 2]], # 13-P7/128
#    [-1, 7, BottleneckCSP, [1024]],  # 14
#   ]
#
# # yolov4-p7 head
# # na = len(anchors[0])
# head:
#   [[-1, 1, SPPCSP, [512]], # 15
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-6, 1, Conv, [512, 1, 1]], # route backbone P6
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 20
#    [-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-13, 1, Conv, [512, 1, 1]], # route backbone P5
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [512]], # 25
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-20, 1, Conv, [256, 1, 1]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [256]], # 30
#    [-1, 1, Conv, [128, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [-27, 1, Conv, [128, 1, 1]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP2, [128]], # 35
#    [-1, 1, Conv, [256, 3, 1]],
#    [-2, 1, Conv, [256, 3, 2]],
#    [[-1, 30], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [256]], # 39
#    [-1, 1, Conv, [512, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 25], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 43
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 20], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 47
#    [-1, 1, Conv, [1024, 3, 1]],
#    [-2, 1, Conv, [512, 3, 2]],
#    [[-1, 15], 1, Concat, [1]],  # cat
#    [-1, 3, BottleneckCSP2, [512]], # 51
#    [-1, 1, Conv, [1024, 3, 1]],
#
#    [[36,40,44,48,52], 1, Detect, [nc, anchors]],   # Detect(P3, P4, P5, P6, P7)
#   ]

# %% [markdown]
# ## train

# %%
# !python train.py --img 1024 \
                 --batch 6 \
                 --epochs 150 \
                 --data /app/_data/ScaledYOLOv4/data/DataFile/data.yaml \
                 --cfg /app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml \
                 --weights /app/_data/ScaledYOLOv4/weights/yolov4-p7.pt \
                 --name 5cl_yolov4p7_42 \
                 --cache
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3090', total_memory=24268MB)
#
# Namespace(adam=False, batch_size=6, bucket='', cache_images=True, cfg='/app/_data/ScaledYOLOv4/data/DataFile/customYOLOv4p7.yaml', data='/app/_data/ScaledYOLOv4/data/DataFile/data.yaml', device='', epochs=150, evolve=False, global_rank=-1, hyp='data/hyp.finetune.yaml', img_size=[1024, 1024], local_rank=-1, logdir='runs/', multi_scale=False, name='5cl_yolov4p7_42', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=6, weights='/app/_data/ScaledYOLOv4/weights/yolov4-p7.pt', world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# Hyperparameters {'lr0': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'giou': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.5, 'scale': 0.8, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mixup': 0.2}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1160  models.common.Conv                      [3, 40, 3, 1]
#   1                -1  1     28960  models.common.Conv                      [40, 80, 3, 2]
#   2                -1  1     30960  models.common.BottleneckCSP             [80, 80, 1]
#   3                -1  1    115520  models.common.Conv                      [80, 160, 3, 2]
#   4                -1  1    251360  models.common.BottleneckCSP             [160, 160, 3]
#   5                -1  1    461440  models.common.Conv                      [160, 320, 3, 2]
#   6                -1  1   4081600  models.common.BottleneckCSP             [320, 320, 15]
#   7                -1  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#   8                -1  1  16304000  models.common.BottleneckCSP             [640, 640, 15]
#   9                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 2]
#  10                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  11                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  12                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  13                -1  1  14748160  models.common.Conv                      [1280, 1280, 3, 2]
#  14                -1  1  32382720  models.common.BottleneckCSP             [1280, 1280, 7]
#  15                -1  1  11888640  models.common.SPPCSP                    [1280, 640, 1]
#  16                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  17                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  18                -6  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  19          [-1, -2]  1         0  models.common.Concat                    [1]
#  20                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  21                -1  1    410880  models.common.Conv                      [640, 640, 1, 1]
#  22                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  23               -13  1    820480  models.common.Conv                      [1280, 640, 1, 1]
#  24          [-1, -2]  1         0  models.common.Concat                    [1]
#  25                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  26                -1  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  27                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  28               -20  1    205440  models.common.Conv                      [640, 320, 1, 1]
#  29          [-1, -2]  1         0  models.common.Concat                    [1]
#  30                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  31                -1  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  32                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  33               -27  1     51520  models.common.Conv                      [320, 160, 1, 1]
#  34          [-1, -2]  1         0  models.common.Concat                    [1]
#  35                -1  1    899200  models.common.BottleneckCSP2            [320, 160, 3]
#  36                -1  1    461440  models.common.Conv                      [160, 320, 3, 1]
#  37                -2  1    461440  models.common.Conv                      [160, 320, 3, 2]
#  38          [-1, 30]  1         0  models.common.Concat                    [1]
#  39                -1  1   3590400  models.common.BottleneckCSP2            [640, 320, 3]
#  40                -1  1   1844480  models.common.Conv                      [320, 640, 3, 1]
#  41                -2  1   1844480  models.common.Conv                      [320, 640, 3, 2]
#  42          [-1, 25]  1         0  models.common.Concat                    [1]
#  43                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  44                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  45                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  46          [-1, 20]  1         0  models.common.Concat                    [1]
#  47                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  48                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  49                -2  1   3687680  models.common.Conv                      [640, 640, 3, 2]
#  50          [-1, 15]  1         0  models.common.Concat                    [1]
#  51                -1  1  14348800  models.common.BottleneckCSP2            [1280, 640, 3]
#  52                -1  1   7375360  models.common.Conv                      [640, 1280, 3, 1]
#  53[36, 40, 44, 48, 52]  1    192200  models.yolo.Detect                      [5, [[13, 17, 22, 25, 27, 66, 55, 41], [57, 88, 112, 69, 69, 177, 136, 138], [136, 138, 287, 114, 134, 275, 268, 248], [268, 248, 232, 504, 445, 416, 640, 640], [812, 393, 477, 808, 1070, 908, 1408, 1408]], [320, 640, 1280, 1280, 1280]]
# Model Summary: 722 layers, 2.86134e+08 parameters, 2.86134e+08 gradients
#
# Transferred 1417/1429 items from /app/_data/ScaledYOLOv4/weights/yolov4-p7.pt
# Optimizer groups: 240 .bias, 247 conv.weight, 235 other
# Scanning images: 100%|████████████████████| 4824/4824 [00:04<00:00, 1123.92it/s]
# Scanning labels /app/_data/yolo4_dataset/resized_yolo_1024_npy/labels.cache (482
# Caching images (13.0GB): 100%|██████████████| 4824/4824 [01:16<00:00, 63.02it/s]
# Scanning images: 100%|████████████████████| 1206/1206 [00:01<00:00, 1105.35it/s]
# Scanning labels /app/_data/yolo4_dataset/resized_yolo_1024_npy/labels.cache (120
# Caching images (3.3GB): 100%|███████████████| 1206/1206 [00:19<00:00, 62.86it/s]
#
# Analyzing anchors... anchors/target = 9.77, Best Possible Recall (BPR) = 1.0000
# Image sizes 1024 train, 1024 test
# Using 6 dataloader workers
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      0/149       23G   0.05956   0.05176   0.02764     0.139        28      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.199       0.721       0.379       0.272
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      1/149     23.1G   0.04652   0.04011   0.01749    0.1041        35      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.323         0.7       0.432       0.351
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      2/149     23.1G   0.04562   0.03984   0.01697    0.1024        29      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.248       0.731        0.45       0.374
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      3/149     23.1G   0.04388   0.03951   0.01651   0.09991        29      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.237       0.712       0.445       0.373
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      4/149     23.1G   0.04202   0.03884   0.01599   0.09685        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.337       0.719       0.461       0.342
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      5/149     23.1G   0.04007   0.03665   0.01572   0.09245        21      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.306       0.709       0.472        0.35
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      6/149     23.1G   0.03943   0.03607   0.01568   0.09117        54      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03        0.26       0.696       0.444       0.367
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      7/149     23.1G   0.03855   0.03557   0.01543   0.08956        29      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.336       0.653       0.462       0.346
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      8/149     23.1G   0.03813   0.03598   0.01512   0.08923        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03         0.3       0.758       0.487       0.394
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#      9/149     23.1G   0.03761   0.03533   0.01494   0.08788        49      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.311       0.804        0.49       0.405
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     10/149     23.1G   0.03702   0.03461   0.01507    0.0867        15      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.336       0.706       0.475       0.403
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     11/149     23.1G   0.03684   0.03464   0.01503   0.08651        30      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.288       0.864       0.486       0.402
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     12/149     23.1G   0.03642   0.03493   0.01485    0.0862        28      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.297       0.833       0.487       0.415
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     13/149     23.1G   0.03609   0.03332   0.01464   0.08406        31      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.305       0.821       0.488       0.412
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     14/149     23.1G   0.03585   0.03429   0.01474   0.08488        41      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03        0.32       0.729       0.497        0.41
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     15/149     23.1G   0.03591    0.0335   0.01469   0.08409        32      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.299       0.794       0.488       0.414
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     16/149     23.1G   0.03549   0.03375   0.01458   0.08383        25      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.311       0.785       0.465       0.374
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     17/149     23.1G   0.03578   0.03387   0.01443   0.08408        28      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.332       0.707       0.477       0.414
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     18/149     23.1G   0.03523   0.03343   0.01437   0.08303        22      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.308       0.816       0.485       0.414
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     19/149     23.1G   0.03501   0.03313   0.01439   0.08253        42      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.322       0.834       0.496       0.415
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     20/149     23.1G   0.03507    0.0332   0.01429   0.08257        26      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.312       0.829       0.483       0.413
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     21/149     23.1G   0.03491   0.03302    0.0144   0.08233        27      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.326        0.82       0.496       0.409
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     22/149     23.1G   0.03461   0.03225   0.01442   0.08128        23      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.314       0.811       0.485       0.417
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     23/149     23.1G   0.03455   0.03247   0.01442   0.08143        44      1024
#                Class      Images     Targets           P           R      mAP@.5
#                  all    1.21e+03    2.77e+03       0.319       0.767       0.464        0.39
#
#      Epoch   gpu_mem      GIoU       obj       cls     total   targets  img_size
#     24